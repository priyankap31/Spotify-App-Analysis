# %% [markdown]
# ## Spotify

# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np 
import re
import io

# %%
Url = "https://open.spotify.com/genre/2021-page?_gl=1*664sci*_gcl_aw*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..*_gcl_dc*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..&_ga=2.226386650.1126420451.1639070958-276745153.1633370169&_gac=1.250228146.1639071096.EAIaIQobChMIhuT9xJ_X9AIV1X0rCh1qPg7aEAAYASAAEgIO6_D_BwE"

# %%
html_text = requests.get(Url).text
soup = BeautifulSoup(html_text,"lxml")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-css3-filters no-focus-outline" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   2021 Wrapped on Spotify\n  </title>\n  <meta content="" name="description"/>\n  <meta content="notranslate" property="google"/>\n  <meta content="174829003346" property="fb:app_id"/>\n  <meta content="2021 Wrapped" property="og:title"/>\n  <meta content="" property="og:description"/>\n  <meta content="https://open.spotify.com/genre/2021-page" property="og:url"/>\n  <meta content="" property="og:image"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Spotify" property="og:site_name"/>\n  <meta content="Spotify" property="al:android:app_name"/>\n  <meta content="com.spotify.music" property="al:android:package"/>\n  <meta content="spotify://genre/2021-page?_gl=1*664sci*_gcl_aw*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..*_gcl_dc*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..&amp;_ga=2.226386650.1126420451.1639070958-276745153.1633370169&amp;_gac=1.250228146.1639071096.EAIaIQobChMIhuT9xJ_X9AIV1X0rCh1qPg7aEAAYASAAEgIO6_D_BwE" property="al:android:url"/>\n  <meta content="Spotify" property="al:ios:app_name"/>\n  <meta content="324684580" property="al:ios:app_store_id"/>\n  <meta content="spotify://genre/2021-page?_gl=1*664sci*_gcl_aw*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..*_gcl_dc*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..&amp;_ga=2.226386650.1126420451.1639070958-276745153.1633370169&amp;_gac=1.250228146.1639071096.EAIaIQobChMIhuT9xJ_X9AIV1X0rCh1qPg7aEAAYASAAEgIO6_D_BwE" property="al:ios:url"/>\n  <meta content="@spotify" property="twitter:site"/>\n  <meta content="2021 Wrapped" property="twitter:title"/>\n  <meta content="" property="twitter:description"/>\n  <meta content="" property="twitter:image"/>\n  <meta content="summary" property="twitter:card"/>\n  <link href="https://open.spotify.com/genre/2021-page" rel="canonical"/>\n  <link href="android-app://com.spotify.music/spotify/genre/2021-page?_gl=1*664sci*_gcl_aw*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..*_gcl_dc*R0NMLjE2MzkwNzExODkuRUFJYUlRb2JDaE1JaHVUOXhKX1g5QUlWMVgwckNoMXFQZzdhRUFBWUFTQUFFZ0lPNl9EX0J3RQ..&amp;_ga=2.226386650.1126420451.1639070958-276745153.1633370169&amp;_gac=1.250228146.1639071096.EAIaIQobChMIhuT9xJ_X9AIV1X0rCh1qPg7aEAAYASAAEgIO6_D_BwE" rel="alternate"/>\n  <meta content="width=device-width,initial-scale=1,maximum-scale=1,viewport-fit=cover" name="viewport"/>\n  <script data-testid="config" id="config" type="application/json">\n   {"app_name":"open_page","market":"IN","locale":{"locale":"en","rtl":false,"textDirection":"ltr"},"gtmId":"GTM-PZHN3VD","optimizeId":"GTM-W53X654","userCountry":null,"isPremium":false,"correlationId":"8221680d697a64ccef0af32be2f9f489","retargetingPixels":null}\n  </script>\n  <script id="baba" type="application/json">\n   []\n  </script>\n  <link href="https://open.scdn.co/cdn/build/open/open.475f32b2.css" rel="stylesheet"/>\n  <style type="text/css">\n  </style>\n  <link href="https://open.scdn.co/cdn/images/favicon.0c211e2e.png " rel="icon"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-144.dbd8dd2a.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-114.2fdb1eb2.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-72.cffecbdb.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-57.2d68aabb.png" rel="apple-touch-icon-precomposed"/>\n </head>\n <body id="body">\n  <div class="page">\n   <script>\n    (function() {\n    var setFont = function() {\n        document.documentElement.className += \' fonts-loaded\';\n    } ...

# %%
Url1 = "https://open.spotify.com/playlist/37i9dQZEVXbLZ52XmnySJg"

# %%
html_text1 = requests.get(Url1).text
soup = BeautifulSoup(html_text1,"lxml")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-css3-filters no-focus-outline" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Top 50 - India | Spotify Playlist\n  </title>\n  <meta content="Listen now only on Spotify: Your daily update of the most played tracks right now - India." name="description"/>\n  <meta content="notranslate" property="google"/>\n  <meta content="174829003346" property="fb:app_id"/>\n  <meta content="Top 50 - India" property="og:title"/>\n  <meta content="Spotify · Playlist · 50 songs · 262.1K likes" property="og:description"/>\n  <meta content="https://open.spotify.com/playlist/37i9dQZEVXbLZ52XmnySJg" property="og:url"/>\n  <meta content="https://charts-images.scdn.co/assets/locale_en/regional/daily/region_in_large.jpg" property="og:image"/>\n  <meta content="music.playlist" property="og:type"/>\n  <meta content="Spotify" property="og:site_name"/>\n  <meta content="AD" property="og:restrictions:country:allowed"/>\n  <meta content="AE" property="og:restrictions:country:allowed"/>\n  <meta content="AG" property="og:restrictions:country:allowed"/>\n  <meta content="AL" property="og:restrictions:country:allowed"/>\n  <meta content="AM" property="og:restrictions:country:allowed"/>\n  <meta content="AO" property="og:restrictions:country:allowed"/>\n  <meta content="AR" property="og:restrictions:country:allowed"/>\n  <meta content="AT" property="og:restrictions:country:allowed"/>\n  <meta content="AU" property="og:restrictions:country:allowed"/>\n  <meta content="AZ" property="og:restrictions:country:allowed"/>\n  <meta content="BA" property="og:restrictions:country:allowed"/>\n  <meta content="BB" property="og:restrictions:country:allowed"/>\n  <meta content="BD" property="og:restrictions:country:allowed"/>\n  <meta content="BE" property="og:restrictions:country:allowed"/>\n  <meta content="BF" property="og:restrictions:country:allowed"/>\n  <meta content="BG" property="og:restrictions:country:allowed"/>\n  <meta content="BH" property="og:restrictions:country:allowed"/>\n  <meta content="BI" property="og:restrictions:country:allowed"/>\n  <meta content="BJ" property="og:restrictions:country:allowed"/>\n  <meta content="BN" property="og:restrictions:country:allowed"/>\n  <meta content="BO" property="og:restrictions:country:allowed"/>\n  <meta content="BR" property="og:restrictions:country:allowed"/>\n  <meta content="BS" property="og:restrictions:country:allowed"/>\n  <meta content="BT" property="og:restrictions:country:allowed"/>\n  <meta content="BW" property="og:restrictions:country:allowed"/>\n  <meta content="BY" property="og:restrictions:country:allowed"/>\n  <meta content="BZ" property="og:restrictions:country:allowed"/>\n  <meta content="CA" property="og:restrictions:country:allowed"/>\n  <meta content="CD" property="og:restrictions:country:allowed"/>\n  <meta content="CG" property="og:restrictions:country:allowed"/>\n  <meta content="CH" property="og:restrictions:country:allowed"/>\n  <meta content="CI" property="og:restrictions:country:allowed"/>\n  <meta content="CL" property="og:restrictions:country:allowed"/>\n  <meta content="CM" property="og:restrictions:country:allowed"/>\n  <meta content="CO" property="og:restrictions:country:allowed"/>\n  <meta content="CR" property="og:restrictions:country:allowed"/>\n  <meta content="CV" property="og:restrictions:country:allowed"/>\n  <meta content="CW" property="og:restrictions:country:allowed"/>\n  <meta content="CY" property="og:restrictions:country:allowed"/>\n  <meta content="CZ" property="og:restrictions:country:allowed"/>\n  <meta content="DE" property="og:restrictions:country:allowed"/>\n  <meta content="DJ" property="og:restrictions:country:allowed"/>\n  <meta content="DK" property="og:restrictions:country:allowed"/>\n  <meta content="DM" property="og:restrictions:country:allowed"/>\n  <meta content="DO" property="og:restrictions:country:allowed"/>\n  <meta content="DZ" property="og:restrictions:country:allowed"/>\n  <meta content="EC" p ...

# %%
Top50_India = soup.find_all("a", tabindex="-1")
for song in Top50_India :
    print(song)
    print(type(song))
# Out:
# <a href="/artist/4f7KfxeHq9BiylGmyXepGt" tabindex="-1"><span dir="auto">Tanishk Bagchi</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/1tqysapcCh1lWEAc9dIFpa" tabindex="-1"><span dir="auto">Jubin Nautiyal</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/1sVmXkzX2ukc6QvasrDBES" tabindex="-1"><span dir="auto">Asees Kaur</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/2DKSZvMj7Da6rzNVPMgREj" tabindex="-1"><span dir="auto">Raataan Lambiyan (From "Shershaah")</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4ITkqBlf5eoVCOFwsJCnqo" tabindex="-1"><span dir="auto">Harrdy Sandhu</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/3tG0IGB24sRhGFLs5F1Km8" tabindex="-1"><span dir="auto">Bijlee Bijlee</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/74OaRjmyh0XyRZsQQQ5l7c" tabindex="-1"><span dir="auto">Jasleen Royal</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/56SjZARoEvag3RoKWIb16j" tabindex="-1"><span dir="auto">B Praak</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/0bRPtPZQkWHeG7MGk9eWlh" tabindex="-1"><span dir="auto">Romy</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4nJ0kto93jDLHQKmpGeYS8" tabindex="-1"><span dir="auto">Anvita Dutt</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/0Z1zYMwJRpvq0d9rdqTOYo" tabindex="-1"><span dir="auto">Ranjha (From "Shershaah")</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/0LyfQWJT6nXafLPZqxe9Of" tabindex="-1"><span dir="auto">Various Artists</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/3fOswFPlmSWKTTFTlksdiv" tabindex="-1"><span dir="auto">HIDDEN GEMS</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/2tIP7SsRs7vjIcLrU85W8J" tabindex="-1"><span dir="auto">The Kid LAROI</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/1uNFoZAHBGtllmzznpCI3s" tabindex="-1"><span dir="auto">Justin Bieber</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/4bZJWQhHKJckFLJuYdvyX2" tabindex="-1"><span dir="auto">F*CK LOVE 3: OVER YOU</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/0y59o4v8uw5crbN9M3JiL1" tabindex="-1"><span dir="auto">Badshah</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/3tPQOjkxO3mrYrrgkTeXgH" tabindex="-1"><span dir="auto">Nikhita Gandhi</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/1tIBidZ4PMZPqWLgunT4IP" tabindex="-1"><span dir="auto">Jugnu</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/048LktY5zMnakWq7PTtFrz" tabindex="-1"><span dir="auto">CKay</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/7iTLGcddv1bOPirdYJjKVy" tabindex="-1"><span dir="auto">Dj Yo!</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5fUXK5m3BNwoRgTyKq8tnz" tabindex="-1"><span dir="auto">AX'EL</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/5NzoKSfocwLOb6o0lXfTM9" tabindex="-1"><span dir="auto">love nwantiti (feat. Dj Yo! &amp; AX'EL) [Remix]</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/0LyfQWJT6nXafLPZqxe9Of" tabindex="-1"><span dir="auto">Various Artists</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/3fOswFPlmSWKTTFTlksdiv" tabindex="-1"><span dir="auto">HIDDEN GEMS</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6aQfrWHwAcuY8IYItbChZh" tabindex="-1"><span dir="auto">Shinda Kahlon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4vvW590Gq8dNWsP5BM9FkS" tabindex="-1"><span dir="auto">Gminxr</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/6EaHaUoczRLrDl5uqxSFW3" tabindex="-1"><span dir="auto">Insane</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/7jVv8c5Fj3E9VhNjxT4snq" tabindex="-1"><span dir="auto">Lil Nas X</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/2LIk90788K0zvyj2JJVwkJ" tabindex="-1"><span dir="auto">Jack Harlow</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/6pOiDiuDQqrmo5DbG0ZubR" tabindex="-1"><span dir="auto">MONTERO</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5NHm4TU5Twz7owibYxJfFU" tabindex="-1"><span dir="auto">King</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/7uftfPn8f7lwtRLUrEVRYM" tabindex="-1"><span dir="auto">The Carnival</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5r3wPya2PpeTTsXsGhQU8O" tabindex="-1"><span dir="auto">Shubh</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/7FdUhWYHba3PgF8tB9ELXo" tabindex="-1"><span dir="auto">We Rollin</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4yvcSjfu4PC0CYQyLy4wSq" tabindex="-1"><span dir="auto">Glass Animals</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/0KTj6k94XZh0c6IEMfxeWV" tabindex="-1"><span dir="auto">Dreamland (+ Bonus Levels)</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4aopF0aU0Nbu5GtSorXV0W" tabindex="-1"><span dir="auto">The PropheC</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/1zIvQYNdDnl4f7iF2s6HHj" tabindex="-1"><span dir="auto">The Lifestyle</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4f7KfxeHq9BiylGmyXepGt" tabindex="-1"><span dir="auto">Tanishk Bagchi</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/0j2LQCxHNcJdkuJRa8KEp5" tabindex="-1"><span dir="auto">Pav Dharia</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/3tPQOjkxO3mrYrrgkTeXgH" tabindex="-1"><span dir="auto">Nikhita Gandhi</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/5zP4OuD73f42dogIjNid68" tabindex="-1"><span dir="auto">Najaa (From "Sooryavanshi")</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/2VSHKHBTiXWplO8lxcnUC9" tabindex="-1"><span dir="auto">GAYLE</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/6tUQPKlpR4x1gjrXTtOImI" tabindex="-1"><span dir="auto">abcdefu</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5L1lO4eRHmJ7a0Q6csE5cT" tabindex="-1"><span dir="auto">LISA</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/4ASxFYWyk2216OloHoaSh8" tabindex="-1"><span dir="auto">LALISA</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/3gBKY0y3dFFVRqicLnVZYz" tabindex="-1"><span dir="auto">Alka Yagnik</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4YRxDV8wJFPHPTeXepOstw" tabindex="-1"><span dir="auto">Arijit Singh</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/5Wm1nhxZqx7i0Hp6ZBqe9T" tabindex="-1"><span dir="auto">Love Forever With Arijit Singh</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4vvW590Gq8dNWsP5BM9FkS" tabindex="-1"><span dir="auto">Gminxr</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6aQfrWHwAcuY8IYItbChZh" tabindex="-1"><span dir="auto">Shinda Kahlon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/1Ac8fcWoMbo35vD3B5Tjqs" tabindex="-1"><span dir="auto">Brown Munde</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/56SjZARoEvag3RoKWIb16j" tabindex="-1"><span dir="auto">B Praak</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/37nWpT1gls52Tu6pymuPw3" tabindex="-1"><span dir="auto">Mann Bharryaa 2.0 (From "Shershaah")</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/3Isy6kedDrgPYoTS1dazA9" tabindex="-1"><span dir="auto">Sean Paul</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6M2wZ9GZgrQXHCFfjv46we" tabindex="-1"><span dir="auto">Dua Lipa</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/5xrOcCoO3jkXRjHQjfESM6" tabindex="-1"><span dir="auto">Mad Love The Prequel</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6RF8hEdlUKoLPQOHmBbHiM" tabindex="-1"><span dir="auto">Yasser Desai</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5f4QpKfy7ptCHwTqspnSJI" tabindex="-1"><span dir="auto">Neha Kakkar</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4yxICw7joYAxRI2sTRldLB" tabindex="-1"><span dir="auto">Rajat Nagpal</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/3PRk98aAwGeeXQsoDa5DGe" tabindex="-1"><span dir="auto">Dil Ko Karaar Aaya (From "Sukoon")</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/2FKWNmZWDBZR4dE5KX4plR" tabindex="-1"><span dir="auto">Diljit Dosanjh</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/0zV96rKdfWliVHNBpAsd2b" tabindex="-1"><span dir="auto">MoonChild Era</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6QrQ7OrISRYIfS5mtacaw2" tabindex="-1"><span dir="auto">Jaymes Young</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/6MuWCR3WPjwyKhqsTKLZ3z" tabindex="-1"><span dir="auto">Feel Something</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/1cNcHeOmjm7yKUYWhrmjMM" tabindex="-1"><span dir="auto">Indravathi Chauhan</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/4tXcR4YBqi96HgZlMCBY7v" tabindex="-1"><span dir="auto">Pushpa - The Rise</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4YRxDV8wJFPHPTeXepOstw" tabindex="-1"><span dir="auto">Arijit Singh</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/3ZxZ03fj3tXBZHZWzvaLSM" tabindex="-1"><span dir="auto">Neeti Mohan</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5r2baeTwcCJnuIsDIlxUJo" tabindex="-1"><span dir="auto">Rashmi Virag</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/1XO82yE4raeQEBSHxrNuSe" tabindex="-1"><span dir="auto">Mere Yaaraa (From "Sooryavanshi")</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4f7KfxeHq9BiylGmyXepGt" tabindex="-1"><span dir="auto">Tanishk Bagchi</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/7C5xVXoqim1TICnCMZ9A6P" tabindex="-1"><span dir="auto">Zahrah S Khan</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/04FsFHujpuqonrPXZrEJlK" tabindex="-1"><span dir="auto">Dev Negi</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/4QsZTMq6EZp26T67ou6ch9" tabindex="-1"><span dir="auto">Kusu Kusu (From "Satyameva Jayate 2")</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/0OS0NZnK7TGIAWx8MkWNFN" tabindex="-1"><span dir="auto">Intense</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/3GkXRRRkV3rfgwG1wJset9" tabindex="-1"><span dir="auto">Excuses</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/6aQfrWHwAcuY8IYItbChZh" tabindex="-1"><span dir="auto">Shinda Kahlon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4vvW590Gq8dNWsP5BM9FkS" tabindex="-1"><span dir="auto">Gminxr</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/0LyfQWJT6nXafLPZqxe9Of" tabindex="-1"><span dir="auto">Various Artists</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/3fOswFPlmSWKTTFTlksdiv" tabindex="-1"><span dir="auto">HIDDEN GEMS</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/09UmIX92EUH9hAK4bxvHx6" tabindex="-1"><span dir="auto">Mithoon</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4YRxDV8wJFPHPTeXepOstw" tabindex="-1"><span dir="auto">Arijit Singh</span></a>
# <class 'bs4.element.Tag'>
# <a href="/artist/4cAERazLlAzVGA10ORWaUP" tabindex="-1"><span dir="auto">Manoj Muntashir</span></a>
# <class 'bs4.element.Tag'>
# <a href="/album/0WtqXJA0EiOtn2fEVOQAxq" tabindex="-1"><span dir="auto">Soch Liya (From "Radhe Shyam")</span></a>
# <class 'bs4.element.Tag'>
# <a class="btn-scroll" href="#upsell" tabindex="-1"><svg viewbox="0 0 80 80"><path d="M40 42L73 6c4-4 10 1 6 6L43 49c-2 2-4 2-6 0L1 12C-3 8 4 2 8 6zm0 27l33-34c4-4 10 1 6 6L43 78c-2 2-4 2-6 0L1 41c-4-4 3-10 7-6z"></path></svg></a>
# <class 'bs4.element.Tag'>

# %%
Top50_India = soup.find_all("a", tabindex="-1")
album = list()
artists = list()
for item in Top50_India:
    i=str(item)
    if "/album" in i:
        album.append(i)
    elif "/artist" in i:
        artists.append(i)

# %%
for item in album:
    print(item)
# Out:
# <a href="/album/2DKSZvMj7Da6rzNVPMgREj" tabindex="-1"><span dir="auto">Raataan Lambiyan (From "Shershaah")</span></a>
# <a href="/album/3tG0IGB24sRhGFLs5F1Km8" tabindex="-1"><span dir="auto">Bijlee Bijlee</span></a>
# <a href="/album/0Z1zYMwJRpvq0d9rdqTOYo" tabindex="-1"><span dir="auto">Ranjha (From "Shershaah")</span></a>
# <a href="/album/3fOswFPlmSWKTTFTlksdiv" tabindex="-1"><span dir="auto">HIDDEN GEMS</span></a>
# <a href="/album/4bZJWQhHKJckFLJuYdvyX2" tabindex="-1"><span dir="auto">F*CK LOVE 3: OVER YOU</span></a>
# <a href="/album/1tIBidZ4PMZPqWLgunT4IP" tabindex="-1"><span dir="auto">Jugnu</span></a>
# <a href="/album/5NzoKSfocwLOb6o0lXfTM9" tabindex="-1"><span dir="auto">love nwantiti (feat. Dj Yo! &amp; AX'EL) [Remix]</span></a>
# <a href="/album/3fOswFPlmSWKTTFTlksdiv" tabindex="-1"><span dir="auto">HIDDEN GEMS</span></a>
# <a href="/album/6EaHaUoczRLrDl5uqxSFW3" tabindex="-1"><span dir="auto">Insane</span></a>
# <a href="/album/6pOiDiuDQqrmo5DbG0ZubR" tabindex="-1"><span dir="auto">MONTERO</span></a>
# <a href="/album/7uftfPn8f7lwtRLUrEVRYM" tabindex="-1"><span dir="auto">The Carnival</span></a>
# <a href="/album/7FdUhWYHba3PgF8tB9ELXo" tabindex="-1"><span dir="auto">We Rollin</span></a>
# <a href="/album/0KTj6k94XZh0c6IEMfxeWV" tabindex="-1"><span dir="auto">Dreamland (+ Bonus Levels)</span></a>
# <a href="/album/1zIvQYNdDnl4f7iF2s6HHj" tabindex="-1"><span dir="auto">The Lifestyle</span></a>
# <a href="/album/5zP4OuD73f42dogIjNid68" tabindex="-1"><span dir="auto">Najaa (From "Sooryavanshi")</span></a>
# <a href="/album/6tUQPKlpR4x1gjrXTtOImI" tabindex="-1"><span dir="auto">abcdefu</span></a>
# <a href="/album/4ASxFYWyk2216OloHoaSh8" tabindex="-1"><span dir="auto">LALISA</span></a>
# <a href="/album/5Wm1nhxZqx7i0Hp6ZBqe9T" tabindex="-1"><span dir="auto">Love Forever With Arijit Singh</span></a>
# <a href="/album/1Ac8fcWoMbo35vD3B5Tjqs" tabindex="-1"><span dir="auto">Brown Munde</span></a>
# <a href="/album/37nWpT1gls52Tu6pymuPw3" tabindex="-1"><span dir="auto">Mann Bharryaa 2.0 (From "Shershaah")</span></a>
# <a href="/album/5xrOcCoO3jkXRjHQjfESM6" tabindex="-1"><span dir="auto">Mad Love The Prequel</span></a>
# <a href="/album/3PRk98aAwGeeXQsoDa5DGe" tabindex="-1"><span dir="auto">Dil Ko Karaar Aaya (From "Sukoon")</span></a>
# <a href="/album/0zV96rKdfWliVHNBpAsd2b" tabindex="-1"><span dir="auto">MoonChild Era</span></a>
# <a href="/album/6MuWCR3WPjwyKhqsTKLZ3z" tabindex="-1"><span dir="auto">Feel Something</span></a>
# <a href="/album/4tXcR4YBqi96HgZlMCBY7v" tabindex="-1"><span dir="auto">Pushpa - The Rise</span></a>
# <a href="/album/1XO82yE4raeQEBSHxrNuSe" tabindex="-1"><span dir="auto">Mere Yaaraa (From "Sooryavanshi")</span></a>
# <a href="/album/4QsZTMq6EZp26T67ou6ch9" tabindex="-1"><span dir="auto">Kusu Kusu (From "Satyameva Jayate 2")</span></a>
# <a href="/album/3GkXRRRkV3rfgwG1wJset9" tabindex="-1"><span dir="auto">Excuses</span></a>
# <a href="/album/3fOswFPlmSWKTTFTlksdiv" tabindex="-1"><span dir="auto">HIDDEN GEMS</span></a>
# <a href="/album/0WtqXJA0EiOtn2fEVOQAxq" tabindex="-1"><span dir="auto">Soch Liya (From "Radhe Shyam")</span></a>

# %%
for item in album : 
    Top50_Songs_India=re.findall(r'>(.*)<',item)[0]
    India_Songs = Top50_Songs_India.replace('''<span dir="auto">''','')
    Top50_Songs_India_Final = India_Songs.replace('''</span>''','')
    print(Top50_Songs_India_Final)
# Out:
# Raataan Lambiyan (From "Shershaah")
# Bijlee Bijlee
# Ranjha (From "Shershaah")
# HIDDEN GEMS
# F*CK LOVE 3: OVER YOU
# Jugnu
# love nwantiti (feat. Dj Yo! &amp; AX'EL) [Remix]
# HIDDEN GEMS
# Insane
# MONTERO
# The Carnival
# We Rollin
# Dreamland (+ Bonus Levels)
# The Lifestyle
# Najaa (From "Sooryavanshi")
# abcdefu
# LALISA
# Love Forever With Arijit Singh
# Brown Munde
# Mann Bharryaa 2.0 (From "Shershaah")
# Mad Love The Prequel
# Dil Ko Karaar Aaya (From "Sukoon")
# MoonChild Era
# Feel Something
# Pushpa - The Rise
# Mere Yaaraa (From "Sooryavanshi")
# Kusu Kusu (From "Satyameva Jayate 2")
# Excuses
# HIDDEN GEMS
# Soch Liya (From "Radhe Shyam")

# %%
for item in artists:
    print(item)
# Out:
# <a href="/artist/4f7KfxeHq9BiylGmyXepGt" tabindex="-1"><span dir="auto">Tanishk Bagchi</span></a>
# <a href="/artist/1tqysapcCh1lWEAc9dIFpa" tabindex="-1"><span dir="auto">Jubin Nautiyal</span></a>
# <a href="/artist/1sVmXkzX2ukc6QvasrDBES" tabindex="-1"><span dir="auto">Asees Kaur</span></a>
# <a href="/artist/4ITkqBlf5eoVCOFwsJCnqo" tabindex="-1"><span dir="auto">Harrdy Sandhu</span></a>
# <a href="/artist/74OaRjmyh0XyRZsQQQ5l7c" tabindex="-1"><span dir="auto">Jasleen Royal</span></a>
# <a href="/artist/56SjZARoEvag3RoKWIb16j" tabindex="-1"><span dir="auto">B Praak</span></a>
# <a href="/artist/0bRPtPZQkWHeG7MGk9eWlh" tabindex="-1"><span dir="auto">Romy</span></a>
# <a href="/artist/4nJ0kto93jDLHQKmpGeYS8" tabindex="-1"><span dir="auto">Anvita Dutt</span></a>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <a href="/artist/0LyfQWJT6nXafLPZqxe9Of" tabindex="-1"><span dir="auto">Various Artists</span></a>
# <a href="/artist/2tIP7SsRs7vjIcLrU85W8J" tabindex="-1"><span dir="auto">The Kid LAROI</span></a>
# <a href="/artist/1uNFoZAHBGtllmzznpCI3s" tabindex="-1"><span dir="auto">Justin Bieber</span></a>
# <a href="/artist/0y59o4v8uw5crbN9M3JiL1" tabindex="-1"><span dir="auto">Badshah</span></a>
# <a href="/artist/3tPQOjkxO3mrYrrgkTeXgH" tabindex="-1"><span dir="auto">Nikhita Gandhi</span></a>
# <a href="/artist/048LktY5zMnakWq7PTtFrz" tabindex="-1"><span dir="auto">CKay</span></a>
# <a href="/artist/7iTLGcddv1bOPirdYJjKVy" tabindex="-1"><span dir="auto">Dj Yo!</span></a>
# <a href="/artist/5fUXK5m3BNwoRgTyKq8tnz" tabindex="-1"><span dir="auto">AX'EL</span></a>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <a href="/artist/0LyfQWJT6nXafLPZqxe9Of" tabindex="-1"><span dir="auto">Various Artists</span></a>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <a href="/artist/6aQfrWHwAcuY8IYItbChZh" tabindex="-1"><span dir="auto">Shinda Kahlon</span></a>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <a href="/artist/4vvW590Gq8dNWsP5BM9FkS" tabindex="-1"><span dir="auto">Gminxr</span></a>
# <a href="/artist/7jVv8c5Fj3E9VhNjxT4snq" tabindex="-1"><span dir="auto">Lil Nas X</span></a>
# <a href="/artist/2LIk90788K0zvyj2JJVwkJ" tabindex="-1"><span dir="auto">Jack Harlow</span></a>
# <a href="/artist/5NHm4TU5Twz7owibYxJfFU" tabindex="-1"><span dir="auto">King</span></a>
# <a href="/artist/5r3wPya2PpeTTsXsGhQU8O" tabindex="-1"><span dir="auto">Shubh</span></a>
# <a href="/artist/4yvcSjfu4PC0CYQyLy4wSq" tabindex="-1"><span dir="auto">Glass Animals</span></a>
# <a href="/artist/4aopF0aU0Nbu5GtSorXV0W" tabindex="-1"><span dir="auto">The PropheC</span></a>
# <a href="/artist/4f7KfxeHq9BiylGmyXepGt" tabindex="-1"><span dir="auto">Tanishk Bagchi</span></a>
# <a href="/artist/0j2LQCxHNcJdkuJRa8KEp5" tabindex="-1"><span dir="auto">Pav Dharia</span></a>
# <a href="/artist/3tPQOjkxO3mrYrrgkTeXgH" tabindex="-1"><span dir="auto">Nikhita Gandhi</span></a>
# <a href="/artist/2VSHKHBTiXWplO8lxcnUC9" tabindex="-1"><span dir="auto">GAYLE</span></a>
# <a href="/artist/5L1lO4eRHmJ7a0Q6csE5cT" tabindex="-1"><span dir="auto">LISA</span></a>
# <a href="/artist/3gBKY0y3dFFVRqicLnVZYz" tabindex="-1"><span dir="auto">Alka Yagnik</span></a>
# <a href="/artist/4YRxDV8wJFPHPTeXepOstw" tabindex="-1"><span dir="auto">Arijit Singh</span></a>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <a href="/artist/4vvW590Gq8dNWsP5BM9FkS" tabindex="-1"><span dir="auto">Gminxr</span></a>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <a href="/artist/6aQfrWHwAcuY8IYItbChZh" tabindex="-1"><span dir="auto">Shinda Kahlon</span></a>
# <a href="/artist/56SjZARoEvag3RoKWIb16j" tabindex="-1"><span dir="auto">B Praak</span></a>
# <a href="/artist/3Isy6kedDrgPYoTS1dazA9" tabindex="-1"><span dir="auto">Sean Paul</span></a>
# <a href="/artist/6M2wZ9GZgrQXHCFfjv46we" tabindex="-1"><span dir="auto">Dua Lipa</span></a>
# <a href="/artist/6RF8hEdlUKoLPQOHmBbHiM" tabindex="-1"><span dir="auto">Yasser Desai</span></a>
# <a href="/artist/5f4QpKfy7ptCHwTqspnSJI" tabindex="-1"><span dir="auto">Neha Kakkar</span></a>
# <a href="/artist/4yxICw7joYAxRI2sTRldLB" tabindex="-1"><span dir="auto">Rajat Nagpal</span></a>
# <a href="/artist/2FKWNmZWDBZR4dE5KX4plR" tabindex="-1"><span dir="auto">Diljit Dosanjh</span></a>
# <a href="/artist/6QrQ7OrISRYIfS5mtacaw2" tabindex="-1"><span dir="auto">Jaymes Young</span></a>
# <a href="/artist/1cNcHeOmjm7yKUYWhrmjMM" tabindex="-1"><span dir="auto">Indravathi Chauhan</span></a>
# <a href="/artist/4YRxDV8wJFPHPTeXepOstw" tabindex="-1"><span dir="auto">Arijit Singh</span></a>
# <a href="/artist/3ZxZ03fj3tXBZHZWzvaLSM" tabindex="-1"><span dir="auto">Neeti Mohan</span></a>
# <a href="/artist/5r2baeTwcCJnuIsDIlxUJo" tabindex="-1"><span dir="auto">Rashmi Virag</span></a>
# <a href="/artist/4f7KfxeHq9BiylGmyXepGt" tabindex="-1"><span dir="auto">Tanishk Bagchi</span></a>
# <a href="/artist/7C5xVXoqim1TICnCMZ9A6P" tabindex="-1"><span dir="auto">Zahrah S Khan</span></a>
# <a href="/artist/04FsFHujpuqonrPXZrEJlK" tabindex="-1"><span dir="auto">Dev Negi</span></a>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <a href="/artist/0OS0NZnK7TGIAWx8MkWNFN" tabindex="-1"><span dir="auto">Intense</span></a>
# <a href="/artist/6LEG9Ld1aLImEFEVHdWNSB" tabindex="-1"><span dir="auto">AP Dhillon</span></a>
# <a href="/artist/6aQfrWHwAcuY8IYItbChZh" tabindex="-1"><span dir="auto">Shinda Kahlon</span></a>
# <a href="/artist/5DHi2MeoRgAwPE0A0qwRMl" tabindex="-1"><span dir="auto">Gurinder Gill</span></a>
# <a href="/artist/4vvW590Gq8dNWsP5BM9FkS" tabindex="-1"><span dir="auto">Gminxr</span></a>
# <a href="/artist/0LyfQWJT6nXafLPZqxe9Of" tabindex="-1"><span dir="auto">Various Artists</span></a>
# <a href="/artist/09UmIX92EUH9hAK4bxvHx6" tabindex="-1"><span dir="auto">Mithoon</span></a>
# <a href="/artist/4YRxDV8wJFPHPTeXepOstw" tabindex="-1"><span dir="auto">Arijit Singh</span></a>
# <a href="/artist/4cAERazLlAzVGA10ORWaUP" tabindex="-1"><span dir="auto">Manoj Muntashir</span></a>

# %%
#top 50 Indian songs artists
for items in artists :
    rep = re.findall(r'>(.*)<',items)[0]
    rep1 = rep.replace('''<span dir="auto">''','')
    Songs_final = rep1.replace('''</span>''','')
    print(Songs_final)
# Out:
# Tanishk Bagchi
# Jubin Nautiyal
# Asees Kaur
# Harrdy Sandhu
# Jasleen Royal
# B Praak
# Romy
# Anvita Dutt
# AP Dhillon
# Gurinder Gill
# Various Artists
# The Kid LAROI
# Justin Bieber
# Badshah
# Nikhita Gandhi
# CKay
# Dj Yo!
# AX'EL
# AP Dhillon
# Gurinder Gill
# Various Artists
# AP Dhillon
# Shinda Kahlon
# Gurinder Gill
# Gminxr
# Lil Nas X
# Jack Harlow
# King
# Shubh
# Glass Animals
# The PropheC
# Tanishk Bagchi
# Pav Dharia
# Nikhita Gandhi
# GAYLE
# LISA
# Alka Yagnik
# Arijit Singh
# AP Dhillon
# Gminxr
# Gurinder Gill
# Shinda Kahlon
# B Praak
# Sean Paul
# Dua Lipa
# Yasser Desai
# Neha Kakkar
# Rajat Nagpal
# Diljit Dosanjh
# Jaymes Young
# Indravathi Chauhan
# Arijit Singh
# Neeti Mohan
# Rashmi Virag
# Tanishk Bagchi
# Zahrah S Khan
# Dev Negi
# AP Dhillon
# Gurinder Gill
# Intense
# AP Dhillon
# Shinda Kahlon
# Gurinder Gill
# Gminxr
# Various Artists
# Mithoon
# Arijit Singh
# Manoj Muntashir

# %%
url = "https://open.spotify.com/"

html_web = requests.get(url).text
soup = BeautifulSoup(html_web,"lxml")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-css3-filters no-focus-outline" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Spotify - Web Player: Music for everyone\n  </title>\n  <meta content="Spotify is a digital music service that gives you access to millions of songs." name="description"/>\n  <meta content="notranslate" property="google"/>\n  <meta content="174829003346" property="fb:app_id"/>\n  <meta content="Spotify - Web Player: Music for everyone" property="og:title"/>\n  <meta content="Spotify is a digital music service that gives you access to millions of songs." property="og:description"/>\n  <meta content="https://open.spotify.com/" property="og:url"/>\n  <meta content="https://open.scdn.co/cdn/images/og-image.860da0d8.png" property="og:image"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Spotify" property="og:site_name"/>\n  <meta content="Spotify" property="al:android:app_name"/>\n  <meta content="com.spotify.music" property="al:android:package"/>\n  <meta content="spotify://" property="al:android:url"/>\n  <meta content="Spotify" property="al:ios:app_name"/>\n  <meta content="324684580" property="al:ios:app_store_id"/>\n  <meta content="spotify://" property="al:ios:url"/>\n  <meta content="@spotify" property="twitter:site"/>\n  <meta content="Spotify - Web Player: Music for everyone" property="twitter:title"/>\n  <meta content="Spotify is a digital music service that gives you access to millions of songs." property="twitter:description"/>\n  <meta content="https://open.scdn.co/cdn/images/og-image.860da0d8.png" property="twitter:image"/>\n  <meta content="summary" property="twitter:card"/>\n  <link href="https://open.spotify.com/" rel="canonical"/>\n  <link href="android-app://com.spotify.music/" rel="alternate"/>\n  <meta content="width=device-width,initial-scale=1,maximum-scale=1,viewport-fit=cover" name="viewport"/>\n  <script data-testid="config" id="config" type="application/json">\n   {"app_name":"open_page","market":"IN","locale":{"locale":"en","rtl":false,"textDirection":"ltr"},"gtmId":"GTM-PZHN3VD","optimizeId":"GTM-W53X654","userCountry":null,"isPremium":false,"correlationId":"5f54ed3c6deee62d5baccb146f1c6b38","retargetingPixels":null}\n  </script>\n  <script id="baba" type="application/json">\n   []\n  </script>\n  <link href="https://open.scdn.co/cdn/build/open/open.475f32b2.css" rel="stylesheet"/>\n  <style type="text/css">\n  </style>\n  <link href="https://open.scdn.co/cdn/images/favicon.0c211e2e.png " rel="icon"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-144.dbd8dd2a.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-114.2fdb1eb2.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-72.cffecbdb.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>\n  <link href="https://open.scdn.co/cdn/images/touch-icon-57.2d68aabb.png" rel="apple-touch-icon-precomposed"/>\n </head>\n <body id="body">\n  <div class="page">\n   <script>\n    (function() {\n    var setFont = function() {\n        document.documentElement.className += \' fonts-loaded\';\n    };\n    if (document.fonts && document.fonts.load) {\n        var fontsToLoad = [\'200 1em \\\'spotify-circular\\\'\', \'600 1em \\\'spotify-circular\\\'\'];\n\n        \n        \n        \n        Promise.all(\n            fontsToLoad.map(function(font) {\n                return document.fonts.load(font);\n            })\n        ).then(setFont).catch(setFont);\n    } else {\n        setFont();\n    }\n})();\n   </script>\n   <svg style="display:none" xmlns="http://www.w3.org/2000/svg">\n    <symbol id="spotify-logo" viewbox="0 0 1000 300">\n     <path d="M8 147C8 65 73 0 155 0s148 65 148 147-66 148-148 148S8 229 8 147zm202 69c10 6 20-10 10-16-39-24-88-30-144-17-12 3-7 21 5 18 51-12 94-6 129 15zm15-40c13 8 25-11 12-19-46-28-112-36-166-20-14 4-7 26 7 22 47-14 107-7 147 17zM71 113c4 ...

# %%
Genres = soup.find_all("span", class_ = "grid-item-image-text")
for types in Genres:
    print(types.text)
# Out:
# Aartis & Bhajans
# Divine Vibes
# Dhyanam
# Namaste Yoga
# Savasana
# Deva Mahadeva
# Sivamayam
# Bollywood Zumba
# 2021 Wrapped
# COVID-19 Guide
# Bollywood
# Punjabi
# Tamil
# EQUAL
# Telugu
# Indie
# Pop

# %%
url = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

html_web = requests.get(url).text
soup = BeautifulSoup(html_web,"lxml")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-css3-filters no-focus-outline" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Top 50 - Global | Spotify Playlist\n  </title>\n  <meta content="Listen now only on Spotify: Your daily update of the most played tracks right now - Global." name="description"/>\n  <meta content="notranslate" property="google"/>\n  <meta content="174829003346" property="fb:app_id"/>\n  <meta content="Top 50 - Global" property="og:title"/>\n  <meta content="Spotify · Playlist · 50 songs · 16.5M likes" property="og:description"/>\n  <meta content="https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF" property="og:url"/>\n  <meta content="https://charts-images.scdn.co/assets/locale_en/regional/daily/region_global_large.jpg" property="og:image"/>\n  <meta content="music.playlist" property="og:type"/>\n  <meta content="Spotify" property="og:site_name"/>\n  <meta content="AD" property="og:restrictions:country:allowed"/>\n  <meta content="AE" property="og:restrictions:country:allowed"/>\n  <meta content="AG" property="og:restrictions:country:allowed"/>\n  <meta content="AL" property="og:restrictions:country:allowed"/>\n  <meta content="AM" property="og:restrictions:country:allowed"/>\n  <meta content="AO" property="og:restrictions:country:allowed"/>\n  <meta content="AR" property="og:restrictions:country:allowed"/>\n  <meta content="AT" property="og:restrictions:country:allowed"/>\n  <meta content="AU" property="og:restrictions:country:allowed"/>\n  <meta content="AZ" property="og:restrictions:country:allowed"/>\n  <meta content="BA" property="og:restrictions:country:allowed"/>\n  <meta content="BB" property="og:restrictions:country:allowed"/>\n  <meta content="BD" property="og:restrictions:country:allowed"/>\n  <meta content="BE" property="og:restrictions:country:allowed"/>\n  <meta content="BF" property="og:restrictions:country:allowed"/>\n  <meta content="BG" property="og:restrictions:country:allowed"/>\n  <meta content="BH" property="og:restrictions:country:allowed"/>\n  <meta content="BI" property="og:restrictions:country:allowed"/>\n  <meta content="BJ" property="og:restrictions:country:allowed"/>\n  <meta content="BN" property="og:restrictions:country:allowed"/>\n  <meta content="BO" property="og:restrictions:country:allowed"/>\n  <meta content="BR" property="og:restrictions:country:allowed"/>\n  <meta content="BS" property="og:restrictions:country:allowed"/>\n  <meta content="BT" property="og:restrictions:country:allowed"/>\n  <meta content="BW" property="og:restrictions:country:allowed"/>\n  <meta content="BY" property="og:restrictions:country:allowed"/>\n  <meta content="BZ" property="og:restrictions:country:allowed"/>\n  <meta content="CA" property="og:restrictions:country:allowed"/>\n  <meta content="CD" property="og:restrictions:country:allowed"/>\n  <meta content="CG" property="og:restrictions:country:allowed"/>\n  <meta content="CH" property="og:restrictions:country:allowed"/>\n  <meta content="CI" property="og:restrictions:country:allowed"/>\n  <meta content="CL" property="og:restrictions:country:allowed"/>\n  <meta content="CM" property="og:restrictions:country:allowed"/>\n  <meta content="CO" property="og:restrictions:country:allowed"/>\n  <meta content="CR" property="og:restrictions:country:allowed"/>\n  <meta content="CV" property="og:restrictions:country:allowed"/>\n  <meta content="CW" property="og:restrictions:country:allowed"/>\n  <meta content="CY" property="og:restrictions:country:allowed"/>\n  <meta content="CZ" property="og:restrictions:country:allowed"/>\n  <meta content="DE" property="og:restrictions:country:allowed"/>\n  <meta content="DJ" property="og:restrictions:country:allowed"/>\n  <meta content="DK" property="og:restrictions:country:allowed"/>\n  <meta content="DM" property="og:restrictions:country:allowed"/>\n  <meta content="DO" property="og:restrictions:country:allowed"/>\n  <meta content="DZ" property="og:restrictions:country:allowed"/>\n  <meta content= ...

# %%
Top50_Global = soup.find_all("a", tabindex = "-1")
Global_Album = list()
Global_Artists = list()

for Plays in Top50_Global :
    song = str(Plays)
    if "/album" in song :
        Global_Album.append(song)
    if "/artist" in song :
        Global_Artists.append(song)

# %%
for Plays in Global_Album:
    print(Plays)
# Out:
# <a href="/album/61ulfFSmmxMhc2wCdmdMkN" tabindex="-1"><span dir="auto">Merry Christmas</span></a>
# <a href="/album/6tUQPKlpR4x1gjrXTtOImI" tabindex="-1"><span dir="auto">abcdefu</span></a>
# <a href="/album/4bZJWQhHKJckFLJuYdvyX2" tabindex="-1"><span dir="auto">F*CK LOVE 3: OVER YOU</span></a>
# <a href="/album/6egzU9NKfora01qaNbvwfZ" tabindex="-1"><span dir="auto">LAST CHRISTMAS</span></a>
# <a href="/album/21jF5jlMtzo94wbxmJ18aa" tabindex="-1"><span dir="auto">30</span></a>
# <a href="/album/6pOiDiuDQqrmo5DbG0ZubR" tabindex="-1"><span dir="auto">MONTERO</span></a>
# <a href="/album/7wHczdY0ek3FHnfVhk10om" tabindex="-1"><span dir="auto">The Lockdown Sessions</span></a>
# <a href="/album/34wa3zf2prXFMk47t9zHFG" tabindex="-1"><span dir="auto">Merry Christmas From Brenda Lee</span></a>
# <a href="/album/0KTj6k94XZh0c6IEMfxeWV" tabindex="-1"><span dir="auto">Dreamland (+ Bonus Levels)</span></a>
# <a href="/album/53fJVD9LpBKEMqdAF7PW5K" tabindex="-1"><span dir="auto">Christmas (Deluxe Special Edition)</span></a>
# <a href="/album/3wivyOdotHWZ9dcuXMjPKT" tabindex="-1"><span dir="auto">Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)</span></a>
# <a href="/album/1bTgKomQYSkKYPD9UI9W4b" tabindex="-1"><span dir="auto">Enemy (with JID) [from the series Arcane League of Legends]</span></a>
# <a href="/album/27MNgBEnLCKoafz1g2Zu97" tabindex="-1"><span dir="auto">Santa Tell Me</span></a>
# <a href="/album/30eO7X0doSEWKhDLAFLMuW" tabindex="-1"><span dir="auto">The Andy Williams Christmas Album</span></a>
# <a href="/album/0T6QxdJZwYrXPHd829SnqK" tabindex="-1"><span dir="auto">La 167</span></a>
# <a href="/album/32iAEBstCjauDhyKpGjTuq" tabindex="-1"><span dir="auto">=</span></a>
# <a href="/album/58cd90Jkrovggh556JPN9L" tabindex="-1"><span dir="auto">Do It To It</span></a>
# <a href="/album/32iAEBstCjauDhyKpGjTuq" tabindex="-1"><span dir="auto">=</span></a>
# <a href="/album/6leYmQzvQjlUtmpNIL9XYQ" tabindex="-1"><span dir="auto">My Name Is José Feliciano</span></a>
# <a href="/album/1nAQbHeOWTfQzbOoFrvndW" tabindex="-1"><span dir="auto">Planet Her</span></a>
# <a href="/album/2vcGYJcPfXUmCdcXXqqukg" tabindex="-1"><span dir="auto">Everyday Is Christmas (Deluxe Edition)</span></a>
# <a href="/album/0t70lpfTyHEv0uuq21fhdZ" tabindex="-1"><span dir="auto">Wrapped In Red</span></a>
# <a href="/album/06mXfvDsRZNfnsGZvX2zpb" tabindex="-1"><span dir="auto">Music Of The Spheres</span></a>
# <a href="/album/6s84u2TUpR3wdUv4NgKA2j" tabindex="-1"><span dir="auto">SOUR</span></a>
# <a href="/album/63MKT9hwmiMFFdFp5SdB1p" tabindex="-1"><span dir="auto">Under The Mistletoe (Deluxe Edition)</span></a>
# <a href="/album/3aYOF3HVkIr1IzhePfQS7s" tabindex="-1"><span dir="auto">Sleigh Ride</span></a>
# <a href="/album/5tR0alqUd1KMW37vPnsOC4" tabindex="-1"><span dir="auto">Dancing with Strangers (Deluxe Edition, 2019 Remaster)</span></a>
# <a href="/album/6kZ42qRrzov54LcAk4onW9" tabindex="-1"><span dir="auto">Red (Taylor's Version)</span></a>
# <a href="/album/07tZDCAqxSIVEZywk0KDfT" tabindex="-1"><span dir="auto">Fighting Demons</span></a>
# <a href="/album/4XbPmVHP7EYBMoE7ZVjKCU" tabindex="-1"><span dir="auto">Christmas Songs by Sinatra</span></a>

# %%
for Plays in Global_Artists:
    print(Plays)
# Out:
# <a href="/artist/4iHNK0tOyZPYnBU7nGAgpQ" tabindex="-1"><span dir="auto">Mariah Carey</span></a>
# <a href="/artist/2VSHKHBTiXWplO8lxcnUC9" tabindex="-1"><span dir="auto">GAYLE</span></a>
# <a href="/artist/2tIP7SsRs7vjIcLrU85W8J" tabindex="-1"><span dir="auto">The Kid LAROI</span></a>
# <a href="/artist/1uNFoZAHBGtllmzznpCI3s" tabindex="-1"><span dir="auto">Justin Bieber</span></a>
# <a href="/artist/5lpH0xAS4fVfLkACg9DAuM" tabindex="-1"><span dir="auto">Wham!</span></a>
# <a href="/artist/4dpARuHxo51G3z768sgnrY" tabindex="-1"><span dir="auto">Adele</span></a>
# <a href="/artist/7jVv8c5Fj3E9VhNjxT4snq" tabindex="-1"><span dir="auto">Lil Nas X</span></a>
# <a href="/artist/2LIk90788K0zvyj2JJVwkJ" tabindex="-1"><span dir="auto">Jack Harlow</span></a>
# <a href="/artist/3PhoLpVuITZKcymswpck5b" tabindex="-1"><span dir="auto">Elton John</span></a>
# <a href="/artist/6M2wZ9GZgrQXHCFfjv46we" tabindex="-1"><span dir="auto">Dua Lipa</span></a>
# <a href="/artist/6n28c9qs9hNGriNa72b26u" tabindex="-1"><span dir="auto">PNAU</span></a>
# <a href="/artist/4cPHsZM98sKzmV26wlwD2W" tabindex="-1"><span dir="auto">Brenda Lee</span></a>
# <a href="/artist/4yvcSjfu4PC0CYQyLy4wSq" tabindex="-1"><span dir="auto">Glass Animals</span></a>
# <a href="/artist/1GxkXlMwML1oSg5eLPiAz3" tabindex="-1"><span dir="auto">Michael Bublé</span></a>
# <a href="/artist/38EmEgXkgK51MT2tPY0EoC" tabindex="-1"><span dir="auto">Bobby Helms</span></a>
# <a href="/artist/53XhwfbYqKCa1cC15pYq2q" tabindex="-1"><span dir="auto">Imagine Dragons</span></a>
# <a href="/artist/6U3ybJ9UHNKEdsH7ktGBZ7" tabindex="-1"><span dir="auto">JID</span></a>
# <a href="/artist/57nPqD7z62gDdq37US9XJR" tabindex="-1"><span dir="auto">Arcane</span></a>
# <a href="/artist/47mIJdHORyRerp4os813jD" tabindex="-1"><span dir="auto">League of Legends</span></a>
# <a href="/artist/66CXWjxzNUsdJxJ2JdwvnR" tabindex="-1"><span dir="auto">Ariana Grande</span></a>
# <a href="/artist/4sj6D0zlMOl25nprDJBiU9" tabindex="-1"><span dir="auto">Andy Williams</span></a>
# <a href="/artist/329e4yvIujISKGKz1BZZbO" tabindex="-1"><span dir="auto">Farruko</span></a>
# <a href="/artist/6eUKZXaKkcviH0Ku9w2n3V" tabindex="-1"><span dir="auto">Ed Sheeran</span></a>
# <a href="/artist/4pnp4w9g30yLfVIAFnZMRd" tabindex="-1"><span dir="auto">ACRAZE</span></a>
# <a href="/artist/1c70yCa8sRgIiQxl3HOEFo" tabindex="-1"><span dir="auto">Cherish</span></a>
# <a href="/artist/6eUKZXaKkcviH0Ku9w2n3V" tabindex="-1"><span dir="auto">Ed Sheeran</span></a>
# <a href="/artist/7K78lVZ8XzkjfRSI7570FF" tabindex="-1"><span dir="auto">José Feliciano</span></a>
# <a href="/artist/5cj0lLjcoR7YOSnhnX0Po5" tabindex="-1"><span dir="auto">Doja Cat</span></a>
# <a href="/artist/5WUlDfRSoLAfcVSX1WnrxN" tabindex="-1"><span dir="auto">Sia</span></a>
# <a href="/artist/3BmGtnKgCSGYIUhmivXKWX" tabindex="-1"><span dir="auto">Kelly Clarkson</span></a>
# <a href="/artist/4gzpq5DPGxSnKTe4SA8HAU" tabindex="-1"><span dir="auto">Coldplay</span></a>
# <a href="/artist/3Nrfpe0tUJi4K4DXYWgMUX" tabindex="-1"><span dir="auto">BTS</span></a>
# <a href="/artist/1McMsnEElThX1knmY4oliG" tabindex="-1"><span dir="auto">Olivia Rodrigo</span></a>
# <a href="/artist/1uNFoZAHBGtllmzznpCI3s" tabindex="-1"><span dir="auto">Justin Bieber</span></a>
# <a href="/artist/7CyeXFnOrfC1N6z4naIpgo" tabindex="-1"><span dir="auto">The Ronettes</span></a>
# <a href="/artist/5KEG7G8LDYlHgFDqZyEEs2" tabindex="-1"><span dir="auto">Chris Rea</span></a>
# <a href="/artist/06HL4z0CvFAxyc27GXpf02" tabindex="-1"><span dir="auto">Taylor Swift</span></a>
# <a href="/artist/4MCBfE4596Uoi2O4DtmEMz" tabindex="-1"><span dir="auto">Juice WRLD</span></a>
# <a href="/artist/0ebNdVaOfp6N0oZ1guIxM8" tabindex="-1"><span dir="auto">SUGA</span></a>
# <a href="/artist/3Nrfpe0tUJi4K4DXYWgMUX" tabindex="-1"><span dir="auto">BTS</span></a>
# <a href="/artist/1Mxqyy3pSjf8kZZL4QVxS0" tabindex="-1"><span dir="auto">Frank Sinatra</span></a>
# <a href="/artist/0JXiS2FrAg3wQYJHcmZdrc" tabindex="-1"><span dir="auto">B. Swanson Quartet</span></a>

# %%
for Plays in Global_Album :
    sk = re.findall(r'>(.*)<',Plays)[0]
    s = sk.replace('''<span dir="auto">''','')
    Songs = s.replace('''</span>''','')
    print(Songs)
# Out:
# Merry Christmas
# abcdefu
# F*CK LOVE 3: OVER YOU
# LAST CHRISTMAS
# 30
# MONTERO
# The Lockdown Sessions
# Merry Christmas From Brenda Lee
# Dreamland (+ Bonus Levels)
# Christmas (Deluxe Special Edition)
# Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)
# Enemy (with JID) [from the series Arcane League of Legends]
# Santa Tell Me
# The Andy Williams Christmas Album
# La 167
# =
# Do It To It
# =
# My Name Is José Feliciano
# Planet Her
# Everyday Is Christmas (Deluxe Edition)
# Wrapped In Red
# Music Of The Spheres
# SOUR
# Under The Mistletoe (Deluxe Edition)
# Sleigh Ride
# Dancing with Strangers (Deluxe Edition, 2019 Remaster)
# Red (Taylor's Version)
# Fighting Demons
# Christmas Songs by Sinatra

# %%
for Plays in Global_Artists :
    sk1 = re.findall(r'>(.*)<',Plays)[0]
    s1= sk1.replace('''<span dir="auto">''','')
    Songs1 = s1.replace('''</span>''','')
    print(Songs1)
# Out:
# Mariah Carey
# GAYLE
# The Kid LAROI
# Justin Bieber
# Wham!
# Adele
# Lil Nas X
# Jack Harlow
# Elton John
# Dua Lipa
# PNAU
# Brenda Lee
# Glass Animals
# Michael Bublé
# Bobby Helms
# Imagine Dragons
# JID
# Arcane
# League of Legends
# Ariana Grande
# Andy Williams
# Farruko
# Ed Sheeran
# ACRAZE
# Cherish
# Ed Sheeran
# José Feliciano
# Doja Cat
# Sia
# Kelly Clarkson
# Coldplay
# BTS
# Olivia Rodrigo
# Justin Bieber
# The Ronettes
# Chris Rea
# Taylor Swift
# Juice WRLD
# SUGA
# BTS
# Frank Sinatra
# B. Swanson Quartet

# %% [markdown]
# ## Playlists

# %%
hiphop_url1 = "https://open.spotify.com/playlist/37i9dQZF1DX9oh43oAzkyx"

web_hh = requests.get(hiphop_url1).text
soup= BeautifulSoup(web_hh,'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-css3-filters no-focus-outline" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Beast Mode Hip-Hop | Spotify Playlist\n  </title>\n  <meta content="Listen now only on Spotify: Energy tracks to get your beast mode on." name="description"/>\n  <meta content="notranslate" property="google"/>\n  <meta content="174829003346" property="fb:app_id"/>\n  <meta content="Beast Mode Hip-Hop" property="og:title"/>\n  <meta content="Spotify · Playlist · 76 songs · 974.9K likes" property="og:description"/>\n  <meta content="https://open.spotify.com/playlist/37i9dQZF1DX9oh43oAzkyx" property="og:url"/>\n  <meta content="https://i.scdn.co/image/ab67706f0000000361b26b89e63392ad9955ce82" property="og:image"/>\n  <meta content="music.playlist" property="og:type"/>\n  <meta content="Spotify" property="og:site_name"/>\n  <meta content="AD" property="og:restrictions:country:allowed"/>\n  <meta content="AE" property="og:restrictions:country:allowed"/>\n  <meta content="AG" property="og:restrictions:country:allowed"/>\n  <meta content="AL" property="og:restrictions:country:allowed"/>\n  <meta content="AM" property="og:restrictions:country:allowed"/>\n  <meta content="AO" property="og:restrictions:country:allowed"/>\n  <meta content="AR" property="og:restrictions:country:allowed"/>\n  <meta content="AT" property="og:restrictions:country:allowed"/>\n  <meta content="AU" property="og:restrictions:country:allowed"/>\n  <meta content="AZ" property="og:restrictions:country:allowed"/>\n  <meta content="BA" property="og:restrictions:country:allowed"/>\n  <meta content="BB" property="og:restrictions:country:allowed"/>\n  <meta content="BD" property="og:restrictions:country:allowed"/>\n  <meta content="BE" property="og:restrictions:country:allowed"/>\n  <meta content="BF" property="og:restrictions:country:allowed"/>\n  <meta content="BG" property="og:restrictions:country:allowed"/>\n  <meta content="BH" property="og:restrictions:country:allowed"/>\n  <meta content="BI" property="og:restrictions:country:allowed"/>\n  <meta content="BJ" property="og:restrictions:country:allowed"/>\n  <meta content="BN" property="og:restrictions:country:allowed"/>\n  <meta content="BO" property="og:restrictions:country:allowed"/>\n  <meta content="BR" property="og:restrictions:country:allowed"/>\n  <meta content="BS" property="og:restrictions:country:allowed"/>\n  <meta content="BT" property="og:restrictions:country:allowed"/>\n  <meta content="BW" property="og:restrictions:country:allowed"/>\n  <meta content="BY" property="og:restrictions:country:allowed"/>\n  <meta content="BZ" property="og:restrictions:country:allowed"/>\n  <meta content="CA" property="og:restrictions:country:allowed"/>\n  <meta content="CD" property="og:restrictions:country:allowed"/>\n  <meta content="CG" property="og:restrictions:country:allowed"/>\n  <meta content="CH" property="og:restrictions:country:allowed"/>\n  <meta content="CI" property="og:restrictions:country:allowed"/>\n  <meta content="CL" property="og:restrictions:country:allowed"/>\n  <meta content="CM" property="og:restrictions:country:allowed"/>\n  <meta content="CO" property="og:restrictions:country:allowed"/>\n  <meta content="CR" property="og:restrictions:country:allowed"/>\n  <meta content="CV" property="og:restrictions:country:allowed"/>\n  <meta content="CW" property="og:restrictions:country:allowed"/>\n  <meta content="CY" property="og:restrictions:country:allowed"/>\n  <meta content="CZ" property="og:restrictions:country:allowed"/>\n  <meta content="DE" property="og:restrictions:country:allowed"/>\n  <meta content="DJ" property="og:restrictions:country:allowed"/>\n  <meta content="DK" property="og:restrictions:country:allowed"/>\n  <meta content="DM" property="og:restrictions:country:allowed"/>\n  <meta content="DO" property="og:restrictions:country:allowed"/>\n  <meta content="DZ" property="og:restrictions:country:allowed"/>\n  <meta content="EC" property="og:restrictions:countr ...

# %%
HipHop_Songs = soup.find_all("a", tabindex="-1")
Albums_hh = list()
Artists_hh = list()
for hh in HipHop_Songs:
    hiphop = str(hh)
    if "/album" in hiphop:
        Albums_hh.append(hiphop)
    elif "/artist" in hiphop:
        Artists_hh.append(hiphop)

# %%
for hh in Albums_hh :
    print(hh)
# Out:
# <a href="/album/4tokbQaFXRrq8keVGBD9vb" tabindex="-1"><span dir="auto">Motley Crew</span></a>
# <a href="/album/3HqmX8hGcbbQZODgayNEYx" tabindex="-1"><span dir="auto">family ties (with Kendrick Lamar)</span></a>
# <a href="/album/4K3SQSfKMXLcVnyUSFELZw" tabindex="-1"><span dir="auto">SUVs (Black on Black)</span></a>
# <a href="/album/6IqDBDKg1kWzZfpKorTv0B" tabindex="-1"><span dir="auto">Back On My Baby Jesus Sh!t AGAIN</span></a>
# <a href="/album/5kE2OAuUYGBqqzscqgBXXf" tabindex="-1"><span dir="auto">KHALED KHALED</span></a>
# <a href="/album/5LuoozUhs2pl3glZeAJl89" tabindex="-1"><span dir="auto">Scary Hours 2</span></a>
# <a href="/album/0hTvuLmKKMWoBWgPPrpUKF" tabindex="-1"><span dir="auto">REPEAT IT</span></a>
# <a href="/album/6M4Nu5UgX097dxeF2lm9P8" tabindex="-1"><span dir="auto">Featuring Ty Dolla $ign</span></a>
# <a href="/album/48ahZJLcagb8VTgRAuv6WQ" tabindex="-1"><span dir="auto">Ramen &amp; OJ</span></a>
# <a href="/album/4ROMS3rcR9JepxAtDRpvc5" tabindex="-1"><span dir="auto">Over The Top (feat. Drake)</span></a>
# <a href="/album/622NFw5Yk0OReMJ2XWcXUh" tabindex="-1"><span dir="auto">INDUSTRY BABY (feat. Jack Harlow)</span></a>
# <a href="/album/0q6qOUfC4ikWtv62KCnoip" tabindex="-1"><span dir="auto">Sharing Locations (feat. Lil Baby &amp; Lil Durk)</span></a>
# <a href="/album/3SpBlxme9WbeQdI9kx7KAV" tabindex="-1"><span dir="auto">Certified Lover Boy</span></a>
# <a href="/album/6N9oICOUm4QT2YpWdKwUlu" tabindex="-1"><span dir="auto">Ball If I Want To</span></a>
# <a href="/album/6wTyGUWGCilBFZ837k5aRi" tabindex="-1"><span dir="auto">SAVAGE MODE II</span></a>
# <a href="/album/36jrqYRpGVpJqztuqCii22" tabindex="-1"><span dir="auto">WHATS POPPIN (feat. DaBaby, Tory Lanez &amp; Lil Wayne) [Remix]</span></a>
# <a href="/album/5oBYG6dEI2Er6EeLnmonGE" tabindex="-1"><span dir="auto">Whoopty</span></a>
# <a href="/album/5kaQQ0Z6RNMSqCRtM1lGn5" tabindex="-1"><span dir="auto">24 (feat. Lil Baby)</span></a>
# <a href="/album/5nNtpPsSUgb9Hlb3dF1gXa" tabindex="-1"><span dir="auto">POPSTAR (feat. Drake)</span></a>
# <a href="/album/4sS5IjHR0YOJQdSTQ8whWz" tabindex="-1"><span dir="auto">Trip At Knight (Complete Edition)</span></a>
# <a href="/album/58zbc1nYIQmLd4rxnH1Blt" tabindex="-1"><span dir="auto">FWMGAB</span></a>
# <a href="/album/6kaYDcX9dNmJE5OU71IUby" tabindex="-1"><span dir="auto">Masterpiece</span></a>
# <a href="/album/2xAPKH0b7vGsyD5xzkPpnI" tabindex="-1"><span dir="auto">AP (Music from the film Boogie)</span></a>
# <a href="/album/6mBVdi3OYfVGmMiT4jXkYz" tabindex="-1"><span dir="auto">Opp Stoppa (feat. 21 Savage)</span></a>
# <a href="/album/5uCEoLCj3ZZZ1EtzQdQWVl" tabindex="-1"><span dir="auto">Life Is Good (feat. Drake)</span></a>
# <a href="/album/7MFj8Fxl8OrEAOyOBSMz51" tabindex="-1"><span dir="auto">Straightenin</span></a>
# <a href="/album/2u1Wc12FWm7X2ueUHCHxJC" tabindex="-1"><span dir="auto">Red Light Green Light</span></a>
# <a href="/album/2UwJ4Nt10VStLczYefhcEV" tabindex="-1"><span dir="auto">Shiesty Season</span></a>
# <a href="/album/3MEKpJ7wSSp6Z661ThjrUJ" tabindex="-1"><span dir="auto">Destined 2 Win</span></a>
# <a href="/album/7IKkHmEk4It4cRdOYanyvW" tabindex="-1"><span dir="auto">Punk</span></a>

# %%
HipHop1 = list()
for hh in Albums_hh:
    hiphop = re.findall(r'>(.*)<',hh)[0]
    hh1= hiphop.replace('''<span dir="auto">''','')
    HipHopSongs = hh1.replace('''</span>''','')
    print(HipHopSongs)
    HipHop1.append(HipHopSongs)
# Out:
# Motley Crew
# family ties (with Kendrick Lamar)
# SUVs (Black on Black)
# Back On My Baby Jesus Sh!t AGAIN
# KHALED KHALED
# Scary Hours 2
# REPEAT IT
# Featuring Ty Dolla $ign
# Ramen &amp; OJ
# Over The Top (feat. Drake)
# INDUSTRY BABY (feat. Jack Harlow)
# Sharing Locations (feat. Lil Baby &amp; Lil Durk)
# Certified Lover Boy
# Ball If I Want To
# SAVAGE MODE II
# WHATS POPPIN (feat. DaBaby, Tory Lanez &amp; Lil Wayne) [Remix]
# Whoopty
# 24 (feat. Lil Baby)
# POPSTAR (feat. Drake)
# Trip At Knight (Complete Edition)
# FWMGAB
# Masterpiece
# AP (Music from the film Boogie)
# Opp Stoppa (feat. 21 Savage)
# Life Is Good (feat. Drake)
# Straightenin
# Red Light Green Light
# Shiesty Season
# Destined 2 Win
# Punk

# %%
print(HipHop1)
# Out:
# ['Motley Crew', 'family ties (with Kendrick Lamar)', 'SUVs (Black on Black)', 'Back On My Baby Jesus Sh!t AGAIN', 'KHALED KHALED', 'Scary Hours 2', 'REPEAT IT', 'Featuring Ty Dolla $ign', 'Ramen &amp; OJ', 'Over The Top (feat. Drake)', 'INDUSTRY BABY (feat. Jack Harlow)', 'Sharing Locations (feat. Lil Baby &amp; Lil Durk)', 'Certified Lover Boy', 'Ball If I Want To', 'SAVAGE MODE II', 'WHATS POPPIN (feat. DaBaby, Tory Lanez &amp; Lil Wayne) [Remix]', 'Whoopty', '24 (feat. Lil Baby)', 'POPSTAR (feat. Drake)', 'Trip At Knight (Complete Edition)', 'FWMGAB', 'Masterpiece', 'AP (Music from the film Boogie)', 'Opp Stoppa (feat. 21 Savage)', 'Life Is Good (feat. Drake)', 'Straightenin', 'Red Light Green Light', 'Shiesty Season', 'Destined 2 Win', 'Punk']

# %%
for hh in Artists_hh :
    print(hh)
# Out:
# <a href="/artist/246dkjvS1zLTtiykXe5h60" tabindex="-1"><span dir="auto">Post Malone</span></a>
# <a href="/artist/5SXuuuRpukkTvsLuUknva1" tabindex="-1"><span dir="auto">Baby Keem</span></a>
# <a href="/artist/2YZyLoL8N0Wb9xBt1NhZWg" tabindex="-1"><span dir="auto">Kendrick Lamar</span></a>
# <a href="/artist/2LIk90788K0zvyj2JJVwkJ" tabindex="-1"><span dir="auto">Jack Harlow</span></a>
# <a href="/artist/5F1aAS1duwlzExnPs3l2Xe" tabindex="-1"><span dir="auto">Pooh Shiesty</span></a>
# <a href="/artist/4r63FhuTkUYltbVAg5TQnk" tabindex="-1"><span dir="auto">DaBaby</span></a>
# <a href="/artist/0QHgL1lAIqAw0HtD7YldmP" tabindex="-1"><span dir="auto">DJ Khaled</span></a>
# <a href="/artist/5f7VJjfbwm532GiveGC0ZK" tabindex="-1"><span dir="auto">Lil Baby</span></a>
# <a href="/artist/3hcs9uc56yIGFCSy9leWe7" tabindex="-1"><span dir="auto">Lil Durk</span></a>
# <a href="/artist/3TVXtAsR1Inumwj472S9r4" tabindex="-1"><span dir="auto">Drake</span></a>
# <a href="/artist/4Ga1P7PMIsmqEZqhYZQgDo" tabindex="-1"><span dir="auto">Lil Tecca</span></a>
# <a href="/artist/2hlmm7s2ICUX0LVIhVFlZQ" tabindex="-1"><span dir="auto">Gunna</span></a>
# <a href="/artist/7c0XG5cIJTrrAgEC3ULPiq" tabindex="-1"><span dir="auto">Ty Dolla $ign</span></a>
# <a href="/artist/246dkjvS1zLTtiykXe5h60" tabindex="-1"><span dir="auto">Post Malone</span></a>
# <a href="/artist/6C1ohJrd5VydigQtaGy5Wa" tabindex="-1"><span dir="auto">Joyner Lucas</span></a>
# <a href="/artist/5f7VJjfbwm532GiveGC0ZK" tabindex="-1"><span dir="auto">Lil Baby</span></a>
# <a href="/artist/6jeg7JBX9J9097esK752iR" tabindex="-1"><span dir="auto">Smiley</span></a>
# <a href="/artist/3TVXtAsR1Inumwj472S9r4" tabindex="-1"><span dir="auto">Drake</span></a>
# <a href="/artist/7jVv8c5Fj3E9VhNjxT4snq" tabindex="-1"><span dir="auto">Lil Nas X</span></a>
# <a href="/artist/2LIk90788K0zvyj2JJVwkJ" tabindex="-1"><span dir="auto">Jack Harlow</span></a>
# <a href="/artist/20sxb77xiYeusSH8cVdatc" tabindex="-1"><span dir="auto">Meek Mill</span></a>
# <a href="/artist/3hcs9uc56yIGFCSy9leWe7" tabindex="-1"><span dir="auto">Lil Durk</span></a>
# <a href="/artist/5f7VJjfbwm532GiveGC0ZK" tabindex="-1"><span dir="auto">Lil Baby</span></a>
# <a href="/artist/3TVXtAsR1Inumwj472S9r4" tabindex="-1"><span dir="auto">Drake</span></a>
# <a href="/artist/4r63FhuTkUYltbVAg5TQnk" tabindex="-1"><span dir="auto">DaBaby</span></a>
# <a href="/artist/1URnnhqYAYcrqrcwql10ft" tabindex="-1"><span dir="auto">21 Savage</span></a>
# <a href="/artist/0iEtIxbK0KxaSlF7G42ZOp" tabindex="-1"><span dir="auto">Metro Boomin</span></a>
# <a href="/artist/2jku7tDXc6XoB6MO2hFuqg" tabindex="-1"><span dir="auto">Tory Lanez</span></a>
# <a href="/artist/2LIk90788K0zvyj2JJVwkJ" tabindex="-1"><span dir="auto">Jack Harlow</span></a>
# <a href="/artist/4r63FhuTkUYltbVAg5TQnk" tabindex="-1"><span dir="auto">DaBaby</span></a>
# <a href="/artist/55Aa2cqylxrFIXC767Z865" tabindex="-1"><span dir="auto">Lil Wayne</span></a>
# <a href="/artist/7arQA31aZVS8yS6zUveWzb" tabindex="-1"><span dir="auto">CJ</span></a>
# <a href="/artist/3Rx4PJ7SP6unkOk5elPUK7" tabindex="-1"><span dir="auto">Money Man</span></a>
# <a href="/artist/5f7VJjfbwm532GiveGC0ZK" tabindex="-1"><span dir="auto">Lil Baby</span></a>
# <a href="/artist/0QHgL1lAIqAw0HtD7YldmP" tabindex="-1"><span dir="auto">DJ Khaled</span></a>
# <a href="/artist/3TVXtAsR1Inumwj472S9r4" tabindex="-1"><span dir="auto">Drake</span></a>
# <a href="/artist/6Xgp2XMz1fhVYe7i6yNAax" tabindex="-1"><span dir="auto">Trippie Redd</span></a>
# <a href="/artist/6AgTAQt8XS6jRWi4sX7w49" tabindex="-1"><span dir="auto">Polo G</span></a>
# <a href="/artist/3hcs9uc56yIGFCSy9leWe7" tabindex="-1"><span dir="auto">Lil Durk</span></a>
# <a href="/artist/6vXTefBL93Dj5IqAWq6OTv" tabindex="-1"><span dir="auto">French Montana</span></a>
# <a href="/artist/4r63FhuTkUYltbVAg5TQnk" tabindex="-1"><span dir="auto">DaBaby</span></a>
# <a href="/artist/0eDvMgVFoNV3TpwtrVCoTj" tabindex="-1"><span dir="auto">Pop Smoke</span></a>
# <a href="/artist/3gGUMEwIX6XodWsYEvKSal" tabindex="-1"><span dir="auto">YBN Nahmir</span></a>
# <a href="/artist/1URnnhqYAYcrqrcwql10ft" tabindex="-1"><span dir="auto">21 Savage</span></a>
# <a href="/artist/1RyvyyTE3xzB2ZywiAwp0i" tabindex="-1"><span dir="auto">Future</span></a>
# <a href="/artist/3TVXtAsR1Inumwj472S9r4" tabindex="-1"><span dir="auto">Drake</span></a>
# <a href="/artist/6oMuImdp5ZcFhWP0ESe6mG" tabindex="-1"><span dir="auto">Migos</span></a>
# <a href="/artist/4r63FhuTkUYltbVAg5TQnk" tabindex="-1"><span dir="auto">DaBaby</span></a>
# <a href="/artist/5F1aAS1duwlzExnPs3l2Xe" tabindex="-1"><span dir="auto">Pooh Shiesty</span></a>
# <a href="/artist/3hcs9uc56yIGFCSy9leWe7" tabindex="-1"><span dir="auto">Lil Durk</span></a>
# <a href="/artist/6jGMq4yGs7aQzuGsMgVgZR" tabindex="-1"><span dir="auto">Lil Tjay</span></a>
# <a href="/artist/6AgTAQt8XS6jRWi4sX7w49" tabindex="-1"><span dir="auto">Polo G</span></a>
# <a href="/artist/14CHVeJGrR5xgUGQFV5BVM" tabindex="-1"><span dir="auto">Fivio Foreign</span></a>
# <a href="/artist/50co4Is1HCEo8bhOyUWKpn" tabindex="-1"><span dir="auto">Young Thug</span></a>
# <a href="/artist/3TVXtAsR1Inumwj472S9r4" tabindex="-1"><span dir="auto">Drake</span></a>
# <a href="/artist/0Y5tJX1MQlPlqiwlOH1tJY" tabindex="-1"><span dir="auto">Travis Scott</span></a>

# %%
HipHopArtist1 = list()
for hh in Artists_hh:
    hiphop_art = re.findall(r'>(.*)<',hh)[0]
    hh2= hiphop_art.replace('''<span dir="auto">''','')
    HipHopArtists = hh2.replace('''</span>''','')
    print(HipHopArtists)
    HipHopArtist1.append(HipHopArtists)
# Out:
# Post Malone
# Baby Keem
# Kendrick Lamar
# Jack Harlow
# Pooh Shiesty
# DaBaby
# DJ Khaled
# Lil Baby
# Lil Durk
# Drake
# Lil Tecca
# Gunna
# Ty Dolla $ign
# Post Malone
# Joyner Lucas
# Lil Baby
# Smiley
# Drake
# Lil Nas X
# Jack Harlow
# Meek Mill
# Lil Durk
# Lil Baby
# Drake
# DaBaby
# 21 Savage
# Metro Boomin
# Tory Lanez
# Jack Harlow
# DaBaby
# Lil Wayne
# CJ
# Money Man
# Lil Baby
# DJ Khaled
# Drake
# Trippie Redd
# Polo G
# Lil Durk
# French Montana
# DaBaby
# Pop Smoke
# YBN Nahmir
# 21 Savage
# Future
# Drake
# Migos
# DaBaby
# Pooh Shiesty
# Lil Durk
# Lil Tjay
# Polo G
# Fivio Foreign
# Young Thug
# Drake
# Travis Scott

# %%
#Playlist2 

hiphop_url2 = "https://open.spotify.com/playlist/37i9dQZF1DWY4xHQp97fN6"

web_hh2 = requests.get(hiphop_url2).text
soup= BeautifulSoup(web_hh2,'lxml')


HipHop_Songs2 = soup.find_all("a", tabindex="-1")
Albums_hh2 = list()
Artists_hh2 = list()
for hh2 in HipHop_Songs2:
    hiphop2 = str(hh2)
    if "/album" in hiphop2:
        Albums_hh2.append(hiphop2)
    elif "/artist" in hiphop2:
        Artists_hh2.append(hiphop2)
        
HipHop2 = list()
for hh2 in Albums_hh2:
    hiphop2 = re.findall(r'>(.*)<',hh2)[0]
    hh2= hiphop2.replace('''<span dir="auto">''','')
    HipHopSongs2 = hh2.replace('''</span>''','')
    print(HipHopSongs2)
    HipHop2.append(HipHopSongs2)
# Out:
# Fighting Demons
# B4 AVA
# Ambition For Cash
# Hall of Fame 2.0
# Too Easy (Remix) [feat. Future &amp; Roddy Ricch]
# family ties (with Kendrick Lamar)
# Sniper Gang Presents Syko Bob &amp; Snapkatt: Nightmare Babies
# Certified Lover Boy
# Yellow Tape 2
# Rambo
# Jumpin (feat. Polo G)
# Pop That Trunk
# Back On My Baby Jesus Sh!t AGAIN
# Me or Sum (feat. Future &amp; Lil Baby)
# I.Y.B.
# Dear God (feat. Kevin Gates)
# They Got Amnesia
# Whole Lotta Red
# Yo!88
# ESCAPE PLAN / MAFIA
# Rocc Climbing (feat. Lil Yachty)
# Chose Me
# Lift Me Up
# Punk
# Life Of A Hotboii
# Expensive Pain
# A Gangsta’s Pain: Reloaded
# They Got Amnesia
# M.E.M 2 Jacksonville (feat. SpotemGottem)
# Certified Lover Boy

# %%
HipHopArtist2 = list()
for hh2 in Artists_hh2:
    hiphop_art2 = re.findall(r'>(.*)<',hh2)[0]
    hh2_1= hiphop_art2.replace('''<span dir="auto">''','')
    HipHopArtists2 = hh2_1.replace('''</span>''','')
    print(HipHopArtists2)
    HipHopArtist2.append(HipHopArtists2)
# Out:
# Juice WRLD
# Polo G
# Trippie Redd
# A Boogie Wit da Hoodie
# Key Glock
# Polo G
# Lil Baby
# Gunna
# Future
# Roddy Ricch
# Baby Keem
# Kendrick Lamar
# Kodak Black
# Drake
# Future
# Young Thug
# Key Glock
# Joyner Lucas
# Lil Durk
# NLE Choppa
# Polo G
# Juicy J
# Wiz Khalifa
# DaBaby
# Nardo Wick
# Future
# Lil Baby
# NLE Choppa
# FL Dusa
# Kevin Gates
# French Montana
# Lil Tjay
# Playboi Carti
# Tm88
# Pi’erre Bourne
# Travis Scott
# Remble
# Lil Yachty
# Blueface
# Blxst
# Tyga
# Young Thug
# Drake
# Travis Scott
# Hotboii
# 42 Dugg
# Moneybagg Yo
# Meek Mill
# Moneybagg Yo
# Moneybagg Yo
# Lil Durk
# EST Gee
# French Montana
# Doja Cat
# Saweetie
# BlocBoy JB
# SpotemGottem
# Drake
# 21 Savage
# Project Pat

# %%
HiphopSongs =list()
HiphopSongs.extend(HipHop1)
HiphopSongs.extend(HipHop2)
HiphopSongs
# Out:
# ['Motley Crew',
#  'family ties (with Kendrick Lamar)',
#  'SUVs (Black on Black)',
#  'Back On My Baby Jesus Sh!t AGAIN',
#  'KHALED KHALED',
#  'Scary Hours 2',
#  'REPEAT IT',
#  'Featuring Ty Dolla $ign',
#  'Ramen &amp; OJ',
#  'Over The Top (feat. Drake)',
#  'INDUSTRY BABY (feat. Jack Harlow)',
#  'Sharing Locations (feat. Lil Baby &amp; Lil Durk)',
#  'Certified Lover Boy',
#  'Ball If I Want To',
#  'SAVAGE MODE II',
#  'WHATS POPPIN (feat. DaBaby, Tory Lanez &amp; Lil Wayne) [Remix]',
#  'Whoopty',
#  '24 (feat. Lil Baby)',
#  'POPSTAR (feat. Drake)',
#  'Trip At Knight (Complete Edition)',
#  'FWMGAB',
#  'Masterpiece',
#  'AP (Music from the film Boogie)',
#  'Opp Stoppa (feat. 21 Savage)',
#  'Life Is Good (feat. Drake)',
#  'Straightenin',
#  'Red Light Green Light',
#  'Shiesty Season',
#  'Destined 2 Win',
#  'Punk',
#  'Fighting Demons',
#  'B4 AVA',
#  'Ambition For Cash',
#  'Hall of Fame 2.0',
#  'Too Easy (Remix) [feat. Future &amp; Roddy Ricch]',
#  'family ties (with Kendrick Lamar)',
#  'Sniper Gang Presents Syko Bob &amp; Snapkatt: Nightmare Babies',
#  'Certified Lover Boy',
#  'Yellow Tape 2',
#  'Rambo',
#  'Jumpin (feat. Polo G)',
#  'Pop That Trunk',
#  'Back On My Baby Jesus Sh!t AGAIN',
#  'Me or Sum (feat. Future &amp; Lil Baby)',
#  'I.Y.B.',
#  'Dear God (feat. Kevin Gates)',
#  'They Got Amnesia',
#  'Whole Lotta Red',
#  'Yo!88',
#  'ESCAPE PLAN / MAFIA',
#  'Rocc Climbing (feat. Lil Yachty)',
#  'Chose Me',
#  'Lift Me Up',
#  'Punk',
#  'Life Of A Hotboii',
#  'Expensive Pain',
#  'A Gangsta’s Pain: Reloaded',
#  'They Got Amnesia',
#  'M.E.M 2 Jacksonville (feat. SpotemGottem)',
#  'Certified Lover Boy']

# %%
HH_Artists = list()
HH_Artists.extend(HipHopArtist1)
HH_Artists.extend(HipHopArtist2)
HH_Artists
# Out:
# ['Post Malone',
#  'Baby Keem',
#  'Kendrick Lamar',
#  'Jack Harlow',
#  'Pooh Shiesty',
#  'DaBaby',
#  'DJ Khaled',
#  'Lil Baby',
#  'Lil Durk',
#  'Drake',
#  'Lil Tecca',
#  'Gunna',
#  'Ty Dolla $ign',
#  'Post Malone',
#  'Joyner Lucas',
#  'Lil Baby',
#  'Smiley',
#  'Drake',
#  'Lil Nas X',
#  'Jack Harlow',
#  'Meek Mill',
#  'Lil Durk',
#  'Lil Baby',
#  'Drake',
#  'DaBaby',
#  '21 Savage',
#  'Metro Boomin',
#  'Tory Lanez',
#  'Jack Harlow',
#  'DaBaby',
#  'Lil Wayne',
#  'CJ',
#  'Money Man',
#  'Lil Baby',
#  'DJ Khaled',
#  'Drake',
#  'Trippie Redd',
#  'Polo G',
#  'Lil Durk',
#  'French Montana',
#  'DaBaby',
#  'Pop Smoke',
#  'YBN Nahmir',
#  '21 Savage',
#  'Future',
#  'Drake',
#  'Migos',
#  'DaBaby',
#  'Pooh Shiesty',
#  'Lil Durk',
#  'Lil Tjay',
#  'Polo G',
#  'Fivio Foreign',
#  'Young Thug',
#  'Drake',
#  'Travis Scott',
#  'Juice WRLD',
#  'Polo G',
#  'Trippie Redd',
#  'A Boogie Wit da Hoodie',
#  'Key Glock',
#  'Polo G',
#  'Lil Baby',
#  'Gunna',
#  'Future',
#  'Roddy Ricch',
#  'Baby Keem',
#  'Kendrick Lamar',
#  'Kodak Black',
#  'Drake',
#  'Future',
#  'Young Thug',
#  'Key Glock',
#  'Joyner Lucas',
#  'Lil Durk',
#  'NLE Choppa',
#  'Polo G',
#  'Juicy J',
#  'Wiz Khalifa',
#  'DaBaby',
#  'Nardo Wick',
#  'Future',
#  'Lil Baby',
#  'NLE Choppa',
#  'FL Dusa',
#  'Kevin Gates',
#  'French Montana',
#  'Lil Tjay',
#  'Playboi Carti',
#  'Tm88',
#  'Pi’erre Bourne',
#  'Travis Scott',
#  'Remble',
#  'Lil Yachty',
#  'Blueface',
#  'Blxst',
#  'Tyga',
#  'Young Thug',
#  'Drake',
#  'Travis Scott',
#  'Hotboii',
#  '42 Dugg',
#  'Moneybagg Yo',
#  'Meek Mill',
#  'Moneybagg Yo',
#  'Moneybagg Yo',
#  'Lil Durk',
#  'EST Gee',
#  'French Montana',
#  'Doja Cat',
#  'Saweetie',
#  'BlocBoy JB',
#  'SpotemGottem',
#  'Drake',
#  '21 Savage',
#  'Project Pat']

# %%
dfa = pd.DataFrame(HH_Artists,columns =['Artists'])
dfa
# Out:
#             Artists
# 0       Post Malone
# 1         Baby Keem
# 2    Kendrick Lamar
# 3       Jack Harlow
# 4      Pooh Shiesty
# ..              ...
# 111      BlocBoy JB
# 112    SpotemGottem
# 113           Drake
# 114       21 Savage
# 115     Project Pat
#
# [116 rows x 1 columns]

# %%
def drop_duplicates(dfa,column_name):
    dfa = dfa.drop_duplicates(subset = column_name)
    return dfa
drop_duplicates(dfa,"Artists")
# Out:
#             Artists
# 0       Post Malone
# 1         Baby Keem
# 2    Kendrick Lamar
# 3       Jack Harlow
# 4      Pooh Shiesty
# ..              ...
# 109        Doja Cat
# 110        Saweetie
# 111      BlocBoy JB
# 112    SpotemGottem
# 115     Project Pat
#
# [62 rows x 1 columns]

# %%
Genre= list()
for i in range(len(HiphopSongs)): 
    Genre.append("HipHop")

# %%
df = pd.DataFrame(HiphopSongs,columns =['Song Name'])
df
# Out:
#                                             Song Name
# 0                                         Motley Crew
# 1                   family ties (with Kendrick Lamar)
# 2                               SUVs (Black on Black)
# 3                    Back On My Baby Jesus Sh!t AGAIN
# 4                                       KHALED KHALED
# 5                                       Scary Hours 2
# 6                                           REPEAT IT
# 7                             Featuring Ty Dolla $ign
# 8                                      Ramen &amp; OJ
# 9                          Over The Top (feat. Drake)
# 10                  INDUSTRY BABY (feat. Jack Harlow)
# 11  Sharing Locations (feat. Lil Baby &amp; Lil Durk)
# 12                                Certified Lover Boy
# 13                                  Ball If I Want To
# 14                                     SAVAGE MODE II
# 15  WHATS POPPIN (feat. DaBaby, Tory Lanez &amp; L...
# 16                                            Whoopty
# 17                                24 (feat. Lil Baby)
# 18                              POPSTAR (feat. Drake)
# 19                  Trip At Knight (Complete Edition)
# 20                                             FWMGAB
# 21                                        Masterpiece
# 22                    AP (Music from the film Boogie)
# 23                       Opp Stoppa (feat. 21 Savage)
# 24                         Life Is Good (feat. Drake)
# 25                                       Straightenin
# 26                              Red Light Green Light
# 27                                     Shiesty Season
# 28                                     Destined 2 Win
# 29                                               Punk
# 30                                    Fighting Demons
# 31                                             B4 AVA
# 32                                  Ambition For Cash
# 33                                   Hall of Fame 2.0
# 34  Too Easy (Remix) [feat. Future &amp; Roddy Ricch]
# 35                  family ties (with Kendrick Lamar)
# 36  Sniper Gang Presents Syko Bob &amp; Snapkatt: ...
# 37                                Certified Lover Boy
# 38                                      Yellow Tape 2
# 39                                              Rambo
# 40                              Jumpin (feat. Polo G)
# 41                                     Pop That Trunk
# 42                   Back On My Baby Jesus Sh!t AGAIN
# 43            Me or Sum (feat. Future &amp; Lil Baby)
# 44                                             I.Y.B.
# 45                       Dear God (feat. Kevin Gates)
# 46                                   They Got Amnesia
# 47                                    Whole Lotta Red
# 48                                              Yo!88
# 49                                ESCAPE PLAN / MAFIA
# 50                   Rocc Climbing (feat. Lil Yachty)
# 51                                           Chose Me
# 52                                         Lift Me Up
# 53                                               Punk
# 54                                  Life Of A Hotboii
# 55                                     Expensive Pain
# 56                         A Gangsta’s Pain: Reloaded
# 57                                   They Got Amnesia
# 58          M.E.M 2 Jacksonville (feat. SpotemGottem)
# 59                                Certified Lover Boy

# %%
df.insert(1, "Genre",Genre, True)
df
# Out:
#                                             Song Name   Genre
# 0                                         Motley Crew  HipHop
# 1                   family ties (with Kendrick Lamar)  HipHop
# 2                               SUVs (Black on Black)  HipHop
# 3                    Back On My Baby Jesus Sh!t AGAIN  HipHop
# 4                                       KHALED KHALED  HipHop
# 5                                       Scary Hours 2  HipHop
# 6                                           REPEAT IT  HipHop
# 7                             Featuring Ty Dolla $ign  HipHop
# 8                                      Ramen &amp; OJ  HipHop
# 9                          Over The Top (feat. Drake)  HipHop
# 10                  INDUSTRY BABY (feat. Jack Harlow)  HipHop
# 11  Sharing Locations (feat. Lil Baby &amp; Lil Durk)  HipHop
# 12                                Certified Lover Boy  HipHop
# 13                                  Ball If I Want To  HipHop
# 14                                     SAVAGE MODE II  HipHop
# 15  WHATS POPPIN (feat. DaBaby, Tory Lanez &amp; L...  HipHop
# 16                                            Whoopty  HipHop
# 17                                24 (feat. Lil Baby)  HipHop
# 18                              POPSTAR (feat. Drake)  HipHop
# 19                  Trip At Knight (Complete Edition)  HipHop
# 20                                             FWMGAB  HipHop
# 21                                        Masterpiece  HipHop
# 22                    AP (Music from the film Boogie)  HipHop
# 23                       Opp Stoppa (feat. 21 Savage)  HipHop
# 24                         Life Is Good (feat. Drake)  HipHop
# 25                                       Straightenin  HipHop
# 26                              Red Light Green Light  HipHop
# 27                                     Shiesty Season  HipHop
# 28                                     Destined 2 Win  HipHop
# 29                                               Punk  HipHop
# 30                                    Fighting Demons  HipHop
# 31                                             B4 AVA  HipHop
# 32                                  Ambition For Cash  HipHop
# 33                                   Hall of Fame 2.0  HipHop
# 34  Too Easy (Remix) [feat. Future &amp; Roddy Ricch]  HipHop
# 35                  family ties (with Kendrick Lamar)  HipHop
# 36  Sniper Gang Presents Syko Bob &amp; Snapkatt: ...  HipHop
# 37                                Certified Lover Boy  HipHop
# 38                                      Yellow Tape 2  HipHop
# 39                                              Rambo  HipHop
# 40                              Jumpin (feat. Polo G)  HipHop
# 41                                     Pop That Trunk  HipHop
# 42                   Back On My Baby Jesus Sh!t AGAIN  HipHop
# 43            Me or Sum (feat. Future &amp; Lil Baby)  HipHop
# 44                                             I.Y.B.  HipHop
# 45                       Dear God (feat. Kevin Gates)  HipHop
# 46                                   They Got Amnesia  HipHop
# 47                                    Whole Lotta Red  HipHop
# 48                                              Yo!88  HipHop
# 49                                ESCAPE PLAN / MAFIA  HipHop
# 50                   Rocc Climbing (feat. Lil Yachty)  HipHop
# 51                                           Chose Me  HipHop
# 52                                         Lift Me Up  HipHop
# 53                                               Punk  HipHop
# 54                                  Life Of A Hotboii  HipHop
# 55                                     Expensive Pain  HipHop
# 56                         A Gangsta’s Pain: Reloaded  HipHop
# 57                                   They Got Amnesia  HipHop
# 58          M.E.M 2 Jacksonville (feat. SpotemGottem)  HipHop
# 59                                Certified Lover Boy  HipHop

# %%
#Indie

Indie_url = "https://open.spotify.com/playlist/37i9dQZF1DX5q67ZpWyRrZ"

web_Indie = requests.get(Indie_url).text
soup= BeautifulSoup(web_Indie,'lxml')


Indie_songs = soup.find_all("a", tabindex="-1")
Albums_Indie = list()
Artists_Indie = list()
for Indie in Indie_songs :
    Indie_Songs = str(Indie)
    if "/album" in Indie_Songs:
        Albums_Indie.append(Indie_Songs)
    elif "/artist" in Indie_Songs:
        Artists_Indie.append(Indie_Songs)

Indie_1=list()

for Indie in Albums_Indie:
    Indie_Songs = re.findall(r'>(.*)<',Indie)[0]
    Indie1= Indie_Songs.replace('''<span dir="auto">''','')
    IndieSongs = Indie1.replace('''</span>''','')
    print(IndieSongs)
    Indie_1.append(IndieSongs)
# Out:
# Baarishein
# Liggi
# Kasoor
# Rangi Saari
# Roz Roz
# Zakir
# Waqt Ki Baatein - Single
# People - Single
# When We Feel Young
# Aalas Ka Pedh
# Jab Tum Miley
# Blush
# Kanaa
# Nanchaku
# Alag Aasmaan
# Aalas Ka Pedh
# Baaraat
# Khoya
# Cool Kids
# Rab Raakha
# Sha- Dobara
# Kaagaz Ki Naav
# Butterflies
# Sukoon
# i'll find my way to you tomorrow
# Pardo
# Side A
# GRIND
# Snake
# Jaago

# %%
for Indie in Artists_Indie:
    Indie_Artists = re.findall(r'>(.*)<',Indie)[0]
    Indie2= Indie_Artists.replace('''<span dir="auto">''','')
    IndieArtists = Indie2.replace('''</span>''','')
    print(IndieArtists)
# Out:
# Anuv Jain
# Ritviz
# Prateek Kuhad
# Kavita Seth
# Kanishk Seth
# The Yellow Diary
# Shilpa Rao
# NAALAYAK
# Dream Note
# Nikhil D'Souza
# When Chai Met Toast
# The Local Train
# Abhilasha Sinha
# Taba Chake
# Nucleya
# 2jaym
# Sublahshini
# Seedhe Maut
# MC STAN
# Anuv Jain
# The Local Train
# Ritviz
# Nucleya
# Zariya
# Aseem
# Kayan
# The Yellow Diary
# Shashwat Sachdev
# Shreya Jain
# Last Minute India
# Nida
# Derric D'souza
# Samar Mehdi
# Kevin Fernando
# Nishu
# Ankur Tewari
# The Ghalat Family
# Emiway Bantai
# MC STAN
# Lifafa

# %%
#Indie Playlist 2 
Indie_url2 = "https://open.spotify.com/playlist/37i9dQZF1DWWuDQ2TxRmCb"

web_Indie2 = requests.get(Indie_url2).text
soup= BeautifulSoup(web_Indie2,'lxml')


Indie_songs2 = soup.find_all("a", tabindex="-1")
Albums_Indie2 = list()
Artists_Indie2 = list()
for Indie2 in Indie_songs2 :
    Indie_Songs2 = str(Indie2)
    if "/album" in Indie_Songs2:
        Albums_Indie2.append(Indie_Songs2)
    elif "/artist" in Indie_Songs2:
        Artists_Indie2.append(Indie_Songs2)
        
Indie_2=list()            
for Indie2 in Albums_Indie2:
    Indie_Songs2 = re.findall(r'>(.*)<',Indie2)[0]
    Indie2= Indie_Songs2.replace('''<span dir="auto">''','')
    IndieSongs2 = Indie2.replace('''</span>''','')
    print(IndieSongs2)
    Indie_2.append(IndieSongs2)
# Out:
# Raunakein (From Sonic Roots - Songs of Soil)
# Rangi Saari
# Runak Jhunak
# Bhammariyo
# Mehndi Te Vavi
# Latthay Di Chaadar - Single
# Pagdandi
# Ae Re Sakhi
# Ekla Cholo Re
# Chhaap Tilak
# Moti Veraana (From Songs of Faith)
# Jheeni Jheeni
# Mitho Laage (The Dewarists, Season 5)
# Haalyo Jaa (Secret Sessions X Collab Stories)
# Panchrang
# Maye Ni Meriye
# Ranjhana
# Tedo Tedo (From Sonic Roots - Songs of Soil)
# Kimaya
# Matwari
# Achint &amp; The Khan Brothers
# Genda Phool (Gujarati Version)
# Radhe (From Songs of Faith)
# Banna
# Purvayi
# Ek Nazar
# Kabir Cafe Live
# Desert Sessions
# Aaj Rang Hai
# Tanna Na

# %%
for Indie2 in Artists_Indie2:
    Indie_Artists2 = re.findall(r'>(.*)<',Indie2)[0]
    Indie2_1= Indie_Artists2.replace('''<span dir="auto">''','')
    IndieArtists2 = Indie2_1.replace('''</span>''','')
    print(IndieArtists2)
# Out:
# Amit Trivedi
# Bhanwari Devi
# Kavita Seth
# Krishan Kumar
# Kavita Seth
# Kanishk Seth
# Kanika Patawari
# Divya Kumar
# Shruti Pathak
# Lost Stories
# Jonita Gandhi
# Hari &amp; Sukhmani
# Nyasa
# Gaurav Chati
# Namita Choudhary
# Paroma Dasgupta
# Shreyas Puranik
# Rahul Vaidya
# Palak Muchhal
# Amit Trivedi
# Osman Mir
# Jonita Gandhi
# Swaroop Khan
# Salim–Sulaiman
# Dhruv Ghanekar
# Mame Khan
# Kushal Chokshi
# Jaysinh Gadhvi
# Kavi Shree Ghanshyam Gadhvi
# Bhargav Purohit
# Raju Bhaai
# Sagar Patel
# Kabir Cafe
# Britto Khangchian
# Akanksha Bhandari
# Sez on the Beat
# Amit Trivedi
# Kirtidan Gadhvi
# Masala Coffee
# Samahita Narang
# Achint
# Badshah
# Bhoomi Trivedi
# Amit Trivedi
# Neeraj Arya
# Arunima Bhattacharya
# Divya Kumar
# Midival Punditz
# Papon
# Kavita Seth
# Kabir Cafe
# mame khan
# Vidhi Sharma
# Nyasa

# %%
IndieSongs =list()
IndieSongs.extend(Indie_1)
IndieSongs.extend(Indie_2)
IndieSongs
# Out:
# ['Baarishein',
#  'Liggi',
#  'Kasoor',
#  'Rangi Saari',
#  'Roz Roz',
#  'Zakir',
#  'Waqt Ki Baatein - Single',
#  'People - Single',
#  'When We Feel Young',
#  'Aalas Ka Pedh',
#  'Jab Tum Miley',
#  'Blush',
#  'Kanaa',
#  'Nanchaku',
#  'Alag Aasmaan',
#  'Aalas Ka Pedh',
#  'Baaraat',
#  'Khoya',
#  'Cool Kids',
#  'Rab Raakha',
#  'Sha- Dobara',
#  'Kaagaz Ki Naav',
#  'Butterflies',
#  'Sukoon',
#  "i'll find my way to you tomorrow",
#  'Pardo',
#  'Side A',
#  'GRIND',
#  'Snake',
#  'Jaago',
#  'Raunakein (From Sonic Roots - Songs of Soil)',
#  'Rangi Saari',
#  'Runak Jhunak',
#  'Bhammariyo',
#  'Mehndi Te Vavi',
#  'Latthay Di Chaadar - Single',
#  'Pagdandi',
#  'Ae Re Sakhi',
#  'Ekla Cholo Re',
#  'Chhaap Tilak',
#  'Moti Veraana (From Songs of Faith)',
#  'Jheeni Jheeni',
#  'Mitho Laage (The Dewarists, Season 5)',
#  'Haalyo Jaa (Secret Sessions X Collab Stories)',
#  'Panchrang',
#  'Maye Ni Meriye',
#  'Ranjhana',
#  'Tedo Tedo (From Sonic Roots - Songs of Soil)',
#  'Kimaya',
#  'Matwari',
#  'Achint &amp; The Khan Brothers',
#  'Genda Phool (Gujarati Version)',
#  'Radhe (From Songs of Faith)',
#  'Banna',
#  'Purvayi',
#  'Ek Nazar',
#  'Kabir Cafe Live',
#  'Desert Sessions',
#  'Aaj Rang Hai',
#  'Tanna Na']

# %%
df1 = pd.DataFrame(IndieSongs,columns = ["Song Name"])
df1
# Out:
#                                         Song Name
# 0                                      Baarishein
# 1                                           Liggi
# 2                                          Kasoor
# 3                                     Rangi Saari
# 4                                         Roz Roz
# 5                                           Zakir
# 6                        Waqt Ki Baatein - Single
# 7                                 People - Single
# 8                              When We Feel Young
# 9                                   Aalas Ka Pedh
# 10                                  Jab Tum Miley
# 11                                          Blush
# 12                                          Kanaa
# 13                                       Nanchaku
# 14                                   Alag Aasmaan
# 15                                  Aalas Ka Pedh
# 16                                        Baaraat
# 17                                          Khoya
# 18                                      Cool Kids
# 19                                     Rab Raakha
# 20                                    Sha- Dobara
# 21                                 Kaagaz Ki Naav
# 22                                    Butterflies
# 23                                         Sukoon
# 24               i'll find my way to you tomorrow
# 25                                          Pardo
# 26                                         Side A
# 27                                          GRIND
# 28                                          Snake
# 29                                          Jaago
# 30   Raunakein (From Sonic Roots - Songs of Soil)
# 31                                    Rangi Saari
# 32                                   Runak Jhunak
# 33                                     Bhammariyo
# 34                                 Mehndi Te Vavi
# 35                    Latthay Di Chaadar - Single
# 36                                       Pagdandi
# 37                                    Ae Re Sakhi
# 38                                  Ekla Cholo Re
# 39                                   Chhaap Tilak
# 40             Moti Veraana (From Songs of Faith)
# 41                                  Jheeni Jheeni
# 42          Mitho Laage (The Dewarists, Season 5)
# 43  Haalyo Jaa (Secret Sessions X Collab Stories)
# 44                                      Panchrang
# 45                                 Maye Ni Meriye
# 46                                       Ranjhana
# 47   Tedo Tedo (From Sonic Roots - Songs of Soil)
# 48                                         Kimaya
# 49                                        Matwari
# 50                 Achint &amp; The Khan Brothers
# 51                 Genda Phool (Gujarati Version)
# 52                    Radhe (From Songs of Faith)
# 53                                          Banna
# 54                                        Purvayi
# 55                                       Ek Nazar
# 56                                Kabir Cafe Live
# 57                                Desert Sessions
# 58                                   Aaj Rang Hai
# 59                                       Tanna Na

# %%
Genre1= list()
for i in range(len(IndieSongs)): 
    Genre1.append("Indie")

# %%
df1.insert(1, "Genre",Genre1, True)
df1
# Out:
#                                         Song Name  Genre
# 0                                      Baarishein  Indie
# 1                                           Liggi  Indie
# 2                                          Kasoor  Indie
# 3                                     Rangi Saari  Indie
# 4                                         Roz Roz  Indie
# 5                                           Zakir  Indie
# 6                        Waqt Ki Baatein - Single  Indie
# 7                                 People - Single  Indie
# 8                              When We Feel Young  Indie
# 9                                   Aalas Ka Pedh  Indie
# 10                                  Jab Tum Miley  Indie
# 11                                          Blush  Indie
# 12                                          Kanaa  Indie
# 13                                       Nanchaku  Indie
# 14                                   Alag Aasmaan  Indie
# 15                                  Aalas Ka Pedh  Indie
# 16                                        Baaraat  Indie
# 17                                          Khoya  Indie
# 18                                      Cool Kids  Indie
# 19                                     Rab Raakha  Indie
# 20                                    Sha- Dobara  Indie
# 21                                 Kaagaz Ki Naav  Indie
# 22                                    Butterflies  Indie
# 23                                         Sukoon  Indie
# 24               i'll find my way to you tomorrow  Indie
# 25                                          Pardo  Indie
# 26                                         Side A  Indie
# 27                                          GRIND  Indie
# 28                                          Snake  Indie
# 29                                          Jaago  Indie
# 30   Raunakein (From Sonic Roots - Songs of Soil)  Indie
# 31                                    Rangi Saari  Indie
# 32                                   Runak Jhunak  Indie
# 33                                     Bhammariyo  Indie
# 34                                 Mehndi Te Vavi  Indie
# 35                    Latthay Di Chaadar - Single  Indie
# 36                                       Pagdandi  Indie
# 37                                    Ae Re Sakhi  Indie
# 38                                  Ekla Cholo Re  Indie
# 39                                   Chhaap Tilak  Indie
# 40             Moti Veraana (From Songs of Faith)  Indie
# 41                                  Jheeni Jheeni  Indie
# 42          Mitho Laage (The Dewarists, Season 5)  Indie
# 43  Haalyo Jaa (Secret Sessions X Collab Stories)  Indie
# 44                                      Panchrang  Indie
# 45                                 Maye Ni Meriye  Indie
# 46                                       Ranjhana  Indie
# 47   Tedo Tedo (From Sonic Roots - Songs of Soil)  Indie
# 48                                         Kimaya  Indie
# 49                                        Matwari  Indie
# 50                 Achint &amp; The Khan Brothers  Indie
# 51                 Genda Phool (Gujarati Version)  Indie
# 52                    Radhe (From Songs of Faith)  Indie
# 53                                          Banna  Indie
# 54                                        Purvayi  Indie
# 55                                       Ek Nazar  Indie
# 56                                Kabir Cafe Live  Indie
# 57                                Desert Sessions  Indie
# 58                                   Aaj Rang Hai  Indie
# 59                                       Tanna Na  Indie

# %%
#Pop

Pop_url = "https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M"

web_Pop = requests.get(Pop_url).text
soup= BeautifulSoup(web_Pop,'lxml')
soups = BeautifulSoup(web_Pop,'lxml')


Pop_songs = soups.find_all("a", tabindex="-1")
Albums_Pop = list()
Artists_Pop = list()
for Pop in Pop_songs :
    Pop_songs = str(Pop)
    if "/album" in Pop_songs:
        Albums_Pop.append(Pop_songs)
    elif "/artist" in Pop_songs:
        Artists_Pop.append(Pop_songs)
        
Pop_1 = list()            
for Pop in Albums_Pop:
    Pop_songss = re.findall(r'>(.*)<',Pop)[0]
    Pop= Pop_songss.replace('''<span dir="auto">''','')
    Popsongs = Pop.replace('''</span>''','')
    print(Popsongs)
    Pop_1.append(Popsongs)
# Out:
# abcdefu
# STAY (with Justin Bieber)
# I Hate U
# Easy On Me
# =
# Fighting Demons
# INDUSTRY BABY (feat. Jack Harlow)
# Dreamland
# Cold Heart (PNAU Remix)
# CKay The First
# Planet Her
# Do It To It
# Wandered To LA (with Justin Bieber)
# One Right Now
# Smokin Out The Window
# 30
# =
# Justice
# Enemy (with JID) [from the series Arcane League of Legends]
# My Universe
# It'll Be Okay
# Red (Taylor's Version)
# Better Days (NEIKED x Mae Muller x Polo G)
# Pepas
# Where Are You Now
# Feel Something
# MONTERO
# 30
# Planet Her
# Happier Than Ever (Edit)

# %%
for Pop in Artists_Pop:
    Pop_Artists1 = re.findall(r'>(.*)<',Pop)[0]
    Pops= Pop_Artists1.replace('''<span dir="auto">''','')
    PopArtists = Pops.replace('''</span>''','')
    print(PopArtists)
# Out:
# GAYLE
# The Kid LAROI
# Justin Bieber
# SZA
# Adele
# Ed Sheeran
# Juice WRLD
# SUGA
# BTS
# Lil Nas X
# Jack Harlow
# Glass Animals
# Elton John
# Dua Lipa
# PNAU
# CKay
# Doja Cat
# ACRAZE
# Cherish
# Juice WRLD
# Justin Bieber
# Post Malone
# The Weeknd
# Bruno Mars
# Anderson .Paak
# Silk Sonic
# Adele
# Ed Sheeran
# Justin Bieber
# Imagine Dragons
# JID
# Arcane
# League of Legends
# Coldplay
# BTS
# Shawn Mendes
# Taylor Swift
# NEIKED
# Mae Muller
# Polo G
# Farruko
# Lost Frequencies
# Calum Scott
# Jaymes Young
# Lil Nas X
# Adele
# Doja Cat
# Billie Eilish

# %%
Pop_url2 = "https://open.spotify.com/playlist/37i9dQZF1DWUa8ZRTfalHk"

web_Pop2 = requests.get(Pop_url2).text
soup= BeautifulSoup(web_Pop2,'lxml')


Pop_song2 = soup.find_all("a", tabindex="-1")
Albums_Pop2 = list()
Artists_Pop2 = list()
for Pop2 in Pop_song2 :
    Pop_song2 = str(Pop2)
    if "/album" in Pop_song2:
        Albums_Pop2.append(Pop_song2)
    elif "/artist" in Pop_song2:
        Artists_Pop2.append(Pop_song2)
        
Pop_2 = list()             
for Pop2 in Albums_Pop2:
    Pop_songs2 = re.findall(r'>(.*)<',Pop2)[0]
    Pop2= Pop_songs2.replace('''<span dir="auto">''','')
    Popsongs2 = Pop2.replace('''</span>''','')
    print(Popsongs2)
    Pop_2.append(Popsongs2)
# Out:
# Fighting Demons
# abcdefu
# I AM WOMAN
# GO TO HELL
# Always Been You
# It'll Be Okay
# GROWING UP IS _____
# WYD Now?
# Midnight River (feat. 6LACK)
# I Hate U
# Scenic Drive (The Tape)
# let you
# One Right Now
# Follow Me
# The Motto
# Sunshine
# 30
# Peru
# Feel Something
# Just Look Up (From Don’t Look Up)
# Crisis / Secret / Set Me Free
# 2011
# Seventeen Going Under
# God Must Hate Me
# feel like shit
# Hands On You
# Wandered To LA (with Justin Bieber)
# Story Of My Life (feat. Trippie Redd)
# World Of Walker
# 30

# %%
for Pop2 in Artists_Pop2:
    Pop_Artists2 = re.findall(r'>(.*)<',Pop2)[0]
    Pops2= Pop_Artists2.replace('''<span dir="auto">''','')
    PopArtists2 = Pops2.replace('''</span>''','')
    print(PopArtists2)
# Out:
# Juice WRLD
# SUGA
# BTS
# GAYLE
# Emmy Meli
# Clinton Kane
# Jessie Murph
# Shawn Mendes
# Ruel
# Sadie Jean
# Pink Sweat$
# 6LACK
# SZA
# Khalid
# Ari Lennox
# Smino
# iann dior
# Post Malone
# The Weeknd
# Sam Feldt
# Rita Ora
# Tiësto
# Ava Max
# OneRepublic
# Adele
# Fireboy DML
# Jaymes Young
# Ariana Grande
# Kid Cudi
# Joshua Bassett
# 5 Seconds of Summer
# Sam Fender
# Catie Turner
# Tate McRae
# Austin George
# Juice WRLD
# Justin Bieber
# ILLENIUM
# Sueco
# Trippie Redd
# Alan Walker
# Benjamin Ingrosso
# Adele

# %%
Pop_Genre =list()
Pop_Genre.extend(Pop_1)
Pop_Genre.extend(Pop_2)
Pop_Genre
# Out:
# ['abcdefu',
#  'STAY (with Justin Bieber)',
#  'I Hate U',
#  'Easy On Me',
#  '=',
#  'Fighting Demons',
#  'INDUSTRY BABY (feat. Jack Harlow)',
#  'Dreamland',
#  'Cold Heart (PNAU Remix)',
#  'CKay The First',
#  'Planet Her',
#  'Do It To It',
#  'Wandered To LA (with Justin Bieber)',
#  'One Right Now',
#  'Smokin Out The Window',
#  '30',
#  '=',
#  'Justice',
#  'Enemy (with JID) [from the series Arcane League of Legends]',
#  'My Universe',
#  "It'll Be Okay",
#  "Red (Taylor's Version)",
#  'Better Days (NEIKED x Mae Muller x Polo G)',
#  'Pepas',
#  'Where Are You Now',
#  'Feel Something',
#  'MONTERO',
#  '30',
#  'Planet Her',
#  'Happier Than Ever (Edit)',
#  'Fighting Demons',
#  'abcdefu',
#  'I AM WOMAN',
#  'GO TO HELL',
#  'Always Been You',
#  "It'll Be Okay",
#  'GROWING UP IS _____',
#  'WYD Now?',
#  'Midnight River (feat. 6LACK)',
#  'I Hate U',
#  'Scenic Drive (The Tape)',
#  'let you',
#  'One Right Now',
#  'Follow Me',
#  'The Motto',
#  'Sunshine',
#  '30',
#  'Peru',
#  'Feel Something',
#  'Just Look Up (From Don’t Look Up)',
#  'Crisis / Secret / Set Me Free',
#  '2011',
#  'Seventeen Going Under',
#  'God Must Hate Me',
#  'feel like shit',
#  'Hands On You',
#  'Wandered To LA (with Justin Bieber)',
#  'Story Of My Life (feat. Trippie Redd)',
#  'World Of Walker',
#  '30']

# %%
df2 = pd.DataFrame(Pop_Genre,columns = ["Song Name"])
df2
# Out:
#                                             Song Name
# 0                                             abcdefu
# 1                           STAY (with Justin Bieber)
# 2                                            I Hate U
# 3                                          Easy On Me
# 4                                                   =
# 5                                     Fighting Demons
# 6                   INDUSTRY BABY (feat. Jack Harlow)
# 7                                           Dreamland
# 8                             Cold Heart (PNAU Remix)
# 9                                      CKay The First
# 10                                         Planet Her
# 11                                        Do It To It
# 12                Wandered To LA (with Justin Bieber)
# 13                                      One Right Now
# 14                              Smokin Out The Window
# 15                                                 30
# 16                                                  =
# 17                                            Justice
# 18  Enemy (with JID) [from the series Arcane Leagu...
# 19                                        My Universe
# 20                                      It'll Be Okay
# 21                             Red (Taylor's Version)
# 22         Better Days (NEIKED x Mae Muller x Polo G)
# 23                                              Pepas
# 24                                  Where Are You Now
# 25                                     Feel Something
# 26                                            MONTERO
# 27                                                 30
# 28                                         Planet Her
# 29                           Happier Than Ever (Edit)
# 30                                    Fighting Demons
# 31                                            abcdefu
# 32                                         I AM WOMAN
# 33                                         GO TO HELL
# 34                                    Always Been You
# 35                                      It'll Be Okay
# 36                                GROWING UP IS _____
# 37                                           WYD Now?
# 38                       Midnight River (feat. 6LACK)
# 39                                           I Hate U
# 40                            Scenic Drive (The Tape)
# 41                                            let you
# 42                                      One Right Now
# 43                                          Follow Me
# 44                                          The Motto
# 45                                           Sunshine
# 46                                                 30
# 47                                               Peru
# 48                                     Feel Something
# 49                  Just Look Up (From Don’t Look Up)
# 50                      Crisis / Secret / Set Me Free
# 51                                               2011
# 52                              Seventeen Going Under
# 53                                   God Must Hate Me
# 54                                     feel like shit
# 55                                       Hands On You
# 56                Wandered To LA (with Justin Bieber)
# 57              Story Of My Life (feat. Trippie Redd)
# 58                                    World Of Walker
# 59                                                 30

# %%
Genre2= list()
for i in range(len(Pop_Genre)): 
    Genre2.append("Pop")

# %%
df2.insert(1, "Genre",Genre2, True)
df2
# Out:
#                                             Song Name Genre
# 0                                             abcdefu   Pop
# 1                           STAY (with Justin Bieber)   Pop
# 2                                            I Hate U   Pop
# 3                                          Easy On Me   Pop
# 4                                                   =   Pop
# 5                                     Fighting Demons   Pop
# 6                   INDUSTRY BABY (feat. Jack Harlow)   Pop
# 7                                           Dreamland   Pop
# 8                             Cold Heart (PNAU Remix)   Pop
# 9                                      CKay The First   Pop
# 10                                         Planet Her   Pop
# 11                                        Do It To It   Pop
# 12                Wandered To LA (with Justin Bieber)   Pop
# 13                                      One Right Now   Pop
# 14                              Smokin Out The Window   Pop
# 15                                                 30   Pop
# 16                                                  =   Pop
# 17                                            Justice   Pop
# 18  Enemy (with JID) [from the series Arcane Leagu...   Pop
# 19                                        My Universe   Pop
# 20                                      It'll Be Okay   Pop
# 21                             Red (Taylor's Version)   Pop
# 22         Better Days (NEIKED x Mae Muller x Polo G)   Pop
# 23                                              Pepas   Pop
# 24                                  Where Are You Now   Pop
# 25                                     Feel Something   Pop
# 26                                            MONTERO   Pop
# 27                                                 30   Pop
# 28                                         Planet Her   Pop
# 29                           Happier Than Ever (Edit)   Pop
# 30                                    Fighting Demons   Pop
# 31                                            abcdefu   Pop
# 32                                         I AM WOMAN   Pop
# 33                                         GO TO HELL   Pop
# 34                                    Always Been You   Pop
# 35                                      It'll Be Okay   Pop
# 36                                GROWING UP IS _____   Pop
# 37                                           WYD Now?   Pop
# 38                       Midnight River (feat. 6LACK)   Pop
# 39                                           I Hate U   Pop
# 40                            Scenic Drive (The Tape)   Pop
# 41                                            let you   Pop
# 42                                      One Right Now   Pop
# 43                                          Follow Me   Pop
# 44                                          The Motto   Pop
# 45                                           Sunshine   Pop
# 46                                                 30   Pop
# 47                                               Peru   Pop
# 48                                     Feel Something   Pop
# 49                  Just Look Up (From Don’t Look Up)   Pop
# 50                      Crisis / Secret / Set Me Free   Pop
# 51                                               2011   Pop
# 52                              Seventeen Going Under   Pop
# 53                                   God Must Hate Me   Pop
# 54                                     feel like shit   Pop
# 55                                       Hands On You   Pop
# 56                Wandered To LA (with Justin Bieber)   Pop
# 57              Story Of My Life (feat. Trippie Redd)   Pop
# 58                                    World Of Walker   Pop
# 59                                                 30   Pop

# %%
frames = [df,df1,df2]

# %%
result = pd.concat(frames)

# %%
result = result.reset_index(drop=True)
result.rename(columns = {'Song Name' : 'Track Name','Genre': 'Genre'})
# Out:
#                                 Track Name   Genre
# 0                              Motley Crew  HipHop
# 1        family ties (with Kendrick Lamar)  HipHop
# 2                    SUVs (Black on Black)  HipHop
# 3         Back On My Baby Jesus Sh!t AGAIN  HipHop
# 4                            KHALED KHALED  HipHop
# ..                                     ...     ...
# 175                           Hands On You     Pop
# 176    Wandered To LA (with Justin Bieber)     Pop
# 177  Story Of My Life (feat. Trippie Redd)     Pop
# 178                        World Of Walker     Pop
# 179                                     30     Pop
#
# [180 rows x 2 columns]

# %%
result.to_csv("Spotify_datas_1.csv")

# %%
#Global_Songs

url = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

web = requests.get(url).text

soup = BeautifulSoup(web, "html.parser")

# %%
Artists_g = list()
Albums_g = list()
Global_songs = soup.find_all("a", tabindex = "-1")
for songs in Global_songs:
    Global_songs = str(songs)
    if "/album" in Global_songs:
        Albums_g.append(Global_songs)
    elif "/artist" in Global_songs:
        Artists_g.append(Global_songs)

# %%
for songs in Albums_g :
    print(songs)
# Out:
# <a href="/album/21jF5jlMtzo94wbxmJ18aa" tabindex="-1"><span dir="auto">30</span></a>
# <a href="/album/4bZJWQhHKJckFLJuYdvyX2" tabindex="-1"><span dir="auto">F*CK LOVE 3: OVER YOU</span></a>
# <a href="/album/6tUQPKlpR4x1gjrXTtOImI" tabindex="-1"><span dir="auto">abcdefu</span></a>
# <a href="/album/61ulfFSmmxMhc2wCdmdMkN" tabindex="-1"><span dir="auto">Merry Christmas</span></a>
# <a href="/album/6pOiDiuDQqrmo5DbG0ZubR" tabindex="-1"><span dir="auto">MONTERO</span></a>
# <a href="/album/0KTj6k94XZh0c6IEMfxeWV" tabindex="-1"><span dir="auto">Dreamland (+ Bonus Levels)</span></a>
# <a href="/album/7wHczdY0ek3FHnfVhk10om" tabindex="-1"><span dir="auto">The Lockdown Sessions</span></a>
# <a href="/album/6egzU9NKfora01qaNbvwfZ" tabindex="-1"><span dir="auto">LAST CHRISTMAS</span></a>
# <a href="/album/1bTgKomQYSkKYPD9UI9W4b" tabindex="-1"><span dir="auto">Enemy (with JID) [from the series Arcane League of Legends]</span></a>
# <a href="/album/32iAEBstCjauDhyKpGjTuq" tabindex="-1"><span dir="auto">=</span></a>
# <a href="/album/0T6QxdJZwYrXPHd829SnqK" tabindex="-1"><span dir="auto">La 167</span></a>
# <a href="/album/53fJVD9LpBKEMqdAF7PW5K" tabindex="-1"><span dir="auto">Christmas (Deluxe Special Edition)</span></a>
# <a href="/album/3wivyOdotHWZ9dcuXMjPKT" tabindex="-1"><span dir="auto">Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)</span></a>
# <a href="/album/32iAEBstCjauDhyKpGjTuq" tabindex="-1"><span dir="auto">=</span></a>
# <a href="/album/34wa3zf2prXFMk47t9zHFG" tabindex="-1"><span dir="auto">Merry Christmas From Brenda Lee</span></a>
# <a href="/album/6kZ42qRrzov54LcAk4onW9" tabindex="-1"><span dir="auto">Red (Taylor's Version)</span></a>
# <a href="/album/6s84u2TUpR3wdUv4NgKA2j" tabindex="-1"><span dir="auto">SOUR</span></a>
# <a href="/album/1nAQbHeOWTfQzbOoFrvndW" tabindex="-1"><span dir="auto">Planet Her</span></a>
# <a href="/album/1hJUh5y1ggqqGsCivnRmHw" tabindex="-1"><span dir="auto">I Hate U</span></a>
# <a href="/album/27MNgBEnLCKoafz1g2Zu97" tabindex="-1"><span dir="auto">Santa Tell Me</span></a>
# <a href="/album/58cd90Jkrovggh556JPN9L" tabindex="-1"><span dir="auto">Do It To It</span></a>
# <a href="/album/06mXfvDsRZNfnsGZvX2zpb" tabindex="-1"><span dir="auto">Music Of The Spheres</span></a>
# <a href="/album/30eO7X0doSEWKhDLAFLMuW" tabindex="-1"><span dir="auto">The Andy Williams Christmas Album</span></a>
# <a href="/album/1nAQbHeOWTfQzbOoFrvndW" tabindex="-1"><span dir="auto">Planet Her</span></a>
# <a href="/album/6pOiDiuDQqrmo5DbG0ZubR" tabindex="-1"><span dir="auto">MONTERO</span></a>
# <a href="/album/1nAQbHeOWTfQzbOoFrvndW" tabindex="-1"><span dir="auto">Planet Her</span></a>
# <a href="/album/21jF5jlMtzo94wbxmJ18aa" tabindex="-1"><span dir="auto">30</span></a>
# <a href="/album/2qJw6w5XwQO0PQlSWPu7Tw" tabindex="-1"><span dir="auto">Chosen</span></a>
# <a href="/album/4ASxFYWyk2216OloHoaSh8" tabindex="-1"><span dir="auto">LALISA</span></a>
# <a href="/album/6lheAtw3IcJvflIhLbykih" tabindex="-1"><span dir="auto">CKay The First</span></a>

# %%
songl = list()             
for songs in Albums_g:
    songs1 = re.findall(r'>(.*)<',songs)[0]
    song2= songs1.replace('''<span dir="auto">''','')
    songs2 = song2.replace('''</span>''','')
    songl.append(songs2)

# %%
print(songl)
# Out:
# ['30', 'F*CK LOVE 3: OVER YOU', 'abcdefu', 'Merry Christmas', 'MONTERO', 'Dreamland (+ Bonus Levels)', 'The Lockdown Sessions', 'LAST CHRISTMAS', 'Enemy (with JID) [from the series Arcane League of Legends]', '=', 'La 167', 'Christmas (Deluxe Special Edition)', 'Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)', '=', 'Merry Christmas From Brenda Lee', "Red (Taylor's Version)", 'SOUR', 'Planet Her', 'I Hate U', 'Santa Tell Me', 'Do It To It', 'Music Of The Spheres', 'The Andy Williams Christmas Album', 'Planet Her', 'MONTERO', 'Planet Her', '30', 'Chosen', 'LALISA', 'CKay The First']

# %%
df4 = pd.DataFrame(songl,columns = ["Track Name"])
df4
# Out:
#                                            Track Name
# 0                                                  30
# 1                               F*CK LOVE 3: OVER YOU
# 2                                             abcdefu
# 3                                     Merry Christmas
# 4                                             MONTERO
# 5                          Dreamland (+ Bonus Levels)
# 6                               The Lockdown Sessions
# 7                                      LAST CHRISTMAS
# 8   Enemy (with JID) [from the series Arcane Leagu...
# 9                                                   =
# 10                                             La 167
# 11                 Christmas (Deluxe Special Edition)
# 12  Jingle Bell Rock/Captain Santa Claus (And His ...
# 13                                                  =
# 14                    Merry Christmas From Brenda Lee
# 15                             Red (Taylor's Version)
# 16                                               SOUR
# 17                                         Planet Her
# 18                                           I Hate U
# 19                                      Santa Tell Me
# 20                                        Do It To It
# 21                               Music Of The Spheres
# 22                  The Andy Williams Christmas Album
# 23                                         Planet Her
# 24                                            MONTERO
# 25                                         Planet Her
# 26                                                 30
# 27                                             Chosen
# 28                                             LALISA
# 29                                     CKay The First

# %%
url= "https://open.spotify.com/playlist/37i9dQZEVXbLp5XoPON0wI"

web1 = requests.get(url).text

soup = BeautifulSoup(web1, "html.parser")

# %%
Artists_USA = list()
Albums_USA = list()
Global_songs_USA = soup.find_all("a", tabindex = "-1")
for USA in Global_songs_USA:
    Global_songs_USA = str(USA)
    if "/album" in Global_songs_USA:
        Albums_USA.append(Global_songs_USA)
    elif "/artist" in Global_songs_USA:
        Artists_USA.append(Global_songs_USA)

# %%
for USA in Albums_USA :
    print(USA)
# Out:
# <a href="/album/1hJUh5y1ggqqGsCivnRmHw" tabindex="-1"><span dir="auto">I Hate U</span></a>
# <a href="/album/34wa3zf2prXFMk47t9zHFG" tabindex="-1"><span dir="auto">Merry Christmas From Brenda Lee</span></a>
# <a href="/album/6pOiDiuDQqrmo5DbG0ZubR" tabindex="-1"><span dir="auto">MONTERO</span></a>
# <a href="/album/3wivyOdotHWZ9dcuXMjPKT" tabindex="-1"><span dir="auto">Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)</span></a>
# <a href="/album/61ulfFSmmxMhc2wCdmdMkN" tabindex="-1"><span dir="auto">Merry Christmas</span></a>
# <a href="/album/21jF5jlMtzo94wbxmJ18aa" tabindex="-1"><span dir="auto">30</span></a>
# <a href="/album/0KTj6k94XZh0c6IEMfxeWV" tabindex="-1"><span dir="auto">Dreamland (+ Bonus Levels)</span></a>
# <a href="/album/4bZJWQhHKJckFLJuYdvyX2" tabindex="-1"><span dir="auto">F*CK LOVE 3: OVER YOU</span></a>
# <a href="/album/6tUQPKlpR4x1gjrXTtOImI" tabindex="-1"><span dir="auto">abcdefu</span></a>
# <a href="/album/30eO7X0doSEWKhDLAFLMuW" tabindex="-1"><span dir="auto">The Andy Williams Christmas Album</span></a>
# <a href="/album/4ZZvKnA1YJ2KcwjMmHBinq" tabindex="-1"><span dir="auto">Holiday Inn (Original Motion Picture Soundtrack)</span></a>
# <a href="/album/6kZ42qRrzov54LcAk4onW9" tabindex="-1"><span dir="auto">Red (Taylor's Version)</span></a>
# <a href="/album/16ou1Elgll2ElsdnU4LNzn" tabindex="-1"><span dir="auto">Wandered To LA (with Justin Bieber)</span></a>
# <a href="/album/6s84u2TUpR3wdUv4NgKA2j" tabindex="-1"><span dir="auto">SOUR</span></a>
# <a href="/album/53fJVD9LpBKEMqdAF7PW5K" tabindex="-1"><span dir="auto">Christmas (Deluxe Special Edition)</span></a>
# <a href="/album/3SpBlxme9WbeQdI9kx7KAV" tabindex="-1"><span dir="auto">Certified Lover Boy</span></a>
# <a href="/album/1nAQbHeOWTfQzbOoFrvndW" tabindex="-1"><span dir="auto">Planet Her</span></a>
# <a href="/album/6MvKUOSuPdfH0WLeQjR3eR" tabindex="-1"><span dir="auto">Have A Holly Jolly Christmas</span></a>
# <a href="/album/6egzU9NKfora01qaNbvwfZ" tabindex="-1"><span dir="auto">LAST CHRISTMAS</span></a>
# <a href="/album/2qLI9pIjubUQMlpdmid2sE" tabindex="-1"><span dir="auto">An Evening With Silk Sonic</span></a>
# <a href="/album/1nAQbHeOWTfQzbOoFrvndW" tabindex="-1"><span dir="auto">Planet Her</span></a>
# <a href="/album/6vBGI5522jvPi0ZZuGQNp4" tabindex="-1"><span dir="auto">The Christmas Song (Expanded Edition)</span></a>
# <a href="/album/6leYmQzvQjlUtmpNIL9XYQ" tabindex="-1"><span dir="auto">My Name Is José Feliciano</span></a>
# <a href="/album/3aYOF3HVkIr1IzhePfQS7s" tabindex="-1"><span dir="auto">Sleigh Ride</span></a>
# <a href="/album/4XbPmVHP7EYBMoE7ZVjKCU" tabindex="-1"><span dir="auto">Christmas Songs by Sinatra</span></a>
# <a href="/album/3r46DPIQeBQbjvjjV5mXGg" tabindex="-1"><span dir="auto">The Melodic Blue</span></a>
# <a href="/album/1bTgKomQYSkKYPD9UI9W4b" tabindex="-1"><span dir="auto">Enemy (with JID) [from the series Arcane League of Legends]</span></a>
# <a href="/album/27MNgBEnLCKoafz1g2Zu97" tabindex="-1"><span dir="auto">Santa Tell Me</span></a>
# <a href="/album/3SpBlxme9WbeQdI9kx7KAV" tabindex="-1"><span dir="auto">Certified Lover Boy</span></a>
# <a href="/album/0kxA9Bc8pamypR5GYXmeti" tabindex="-1"><span dir="auto">Sniper Gang Presents Syko Bob &amp; Snapkatt: Nightmare Babies</span></a>

# %%
SONG_USA = list()             
for USA in Albums_g:
    Usa_songs = re.findall(r'>(.*)<',USA)[0]
    song_usa = Usa_songs.replace('''<span dir="auto">''','')
    chart = song_usa.replace('''</span>''','')
    SONG_USA.append(chart)

# %%
print(SONG_USA)
# Out:
# ['30', 'F*CK LOVE 3: OVER YOU', 'abcdefu', 'Merry Christmas', 'MONTERO', 'Dreamland (+ Bonus Levels)', 'The Lockdown Sessions', 'LAST CHRISTMAS', 'Enemy (with JID) [from the series Arcane League of Legends]', '=', 'La 167', 'Christmas (Deluxe Special Edition)', 'Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)', '=', 'Merry Christmas From Brenda Lee', "Red (Taylor's Version)", 'SOUR', 'Planet Her', 'I Hate U', 'Santa Tell Me', 'Do It To It', 'Music Of The Spheres', 'The Andy Williams Christmas Album', 'Planet Her', 'MONTERO', 'Planet Her', '30', 'Chosen', 'LALISA', 'CKay The First']

# %%
df5 = pd.DataFrame(SONG_USA,columns = ["Track Name"])
df5
# Out:
#                                            Track Name
# 0                                                  30
# 1                               F*CK LOVE 3: OVER YOU
# 2                                             abcdefu
# 3                                     Merry Christmas
# 4                                             MONTERO
# 5                          Dreamland (+ Bonus Levels)
# 6                               The Lockdown Sessions
# 7                                      LAST CHRISTMAS
# 8   Enemy (with JID) [from the series Arcane Leagu...
# 9                                                   =
# 10                                             La 167
# 11                 Christmas (Deluxe Special Edition)
# 12  Jingle Bell Rock/Captain Santa Claus (And His ...
# 13                                                  =
# 14                    Merry Christmas From Brenda Lee
# 15                             Red (Taylor's Version)
# 16                                               SOUR
# 17                                         Planet Her
# 18                                           I Hate U
# 19                                      Santa Tell Me
# 20                                        Do It To It
# 21                               Music Of The Spheres
# 22                  The Andy Williams Christmas Album
# 23                                         Planet Her
# 24                                            MONTERO
# 25                                         Planet Her
# 26                                                 30
# 27                                             Chosen
# 28                                             LALISA
# 29                                     CKay The First

# %%
frames = [df4,df5]

Df = pd.concat(frames)
Df
# Out:
#                                            Track Name
# 0                                                  30
# 1                               F*CK LOVE 3: OVER YOU
# 2                                             abcdefu
# 3                                     Merry Christmas
# 4                                             MONTERO
# 5                          Dreamland (+ Bonus Levels)
# 6                               The Lockdown Sessions
# 7                                      LAST CHRISTMAS
# 8   Enemy (with JID) [from the series Arcane Leagu...
# 9                                                   =
# 10                                             La 167
# 11                 Christmas (Deluxe Special Edition)
# 12  Jingle Bell Rock/Captain Santa Claus (And His ...
# 13                                                  =
# 14                    Merry Christmas From Brenda Lee
# 15                             Red (Taylor's Version)
# 16                                               SOUR
# 17                                         Planet Her
# 18                                           I Hate U
# 19                                      Santa Tell Me
# 20                                        Do It To It
# 21                               Music Of The Spheres
# 22                  The Andy Williams Christmas Album
# 23                                         Planet Her
# 24                                            MONTERO
# 25                                         Planet Her
# 26                                                 30
# 27                                             Chosen
# 28                                             LALISA
# 29                                     CKay The First
# 0                                                  30
# 1                               F*CK LOVE 3: OVER YOU
# 2                                             abcdefu
# 3                                     Merry Christmas
# 4                                             MONTERO
# 5                          Dreamland (+ Bonus Levels)
# 6                               The Lockdown Sessions
# 7                                      LAST CHRISTMAS
# 8   Enemy (with JID) [from the series Arcane Leagu...
# 9                                                   =
# 10                                             La 167
# 11                 Christmas (Deluxe Special Edition)
# 12  Jingle Bell Rock/Captain Santa Claus (And His ...
# 13                                                  =
# 14                    Merry Christmas From Brenda Lee
# 15                             Red (Taylor's Version)
# 16                                               SOUR
# 17                                         Planet Her
# 18                                           I Hate U
# 19                                      Santa Tell Me
# 20                                        Do It To It
# 21                               Music Of The Spheres
# 22                  The Andy Williams Christmas Album
# 23                                         Planet Her
# 24                                            MONTERO
# 25                                         Planet Her
# 26                                                 30
# 27                                             Chosen
# 28                                             LALISA
# 29                                     CKay The First

# %%
Df = Df.reset_index(drop=True)
Df
# Out:
#                                            Track Name
# 0                                                  30
# 1                               F*CK LOVE 3: OVER YOU
# 2                                             abcdefu
# 3                                     Merry Christmas
# 4                                             MONTERO
# 5                          Dreamland (+ Bonus Levels)
# 6                               The Lockdown Sessions
# 7                                      LAST CHRISTMAS
# 8   Enemy (with JID) [from the series Arcane Leagu...
# 9                                                   =
# 10                                             La 167
# 11                 Christmas (Deluxe Special Edition)
# 12  Jingle Bell Rock/Captain Santa Claus (And His ...
# 13                                                  =
# 14                    Merry Christmas From Brenda Lee
# 15                             Red (Taylor's Version)
# 16                                               SOUR
# 17                                         Planet Her
# 18                                           I Hate U
# 19                                      Santa Tell Me
# 20                                        Do It To It
# 21                               Music Of The Spheres
# 22                  The Andy Williams Christmas Album
# 23                                         Planet Her
# 24                                            MONTERO
# 25                                         Planet Her
# 26                                                 30
# 27                                             Chosen
# 28                                             LALISA
# 29                                     CKay The First
# 30                                                 30
# 31                              F*CK LOVE 3: OVER YOU
# 32                                            abcdefu
# 33                                    Merry Christmas
# 34                                            MONTERO
# 35                         Dreamland (+ Bonus Levels)
# 36                              The Lockdown Sessions
# 37                                     LAST CHRISTMAS
# 38  Enemy (with JID) [from the series Arcane Leagu...
# 39                                                  =
# 40                                             La 167
# 41                 Christmas (Deluxe Special Edition)
# 42  Jingle Bell Rock/Captain Santa Claus (And His ...
# 43                                                  =
# 44                    Merry Christmas From Brenda Lee
# 45                             Red (Taylor's Version)
# 46                                               SOUR
# 47                                         Planet Her
# 48                                           I Hate U
# 49                                      Santa Tell Me
# 50                                        Do It To It
# 51                               Music Of The Spheres
# 52                  The Andy Williams Christmas Album
# 53                                         Planet Her
# 54                                            MONTERO
# 55                                         Planet Her
# 56                                                 30
# 57                                             Chosen
# 58                                             LALISA
# 59                                     CKay The First

# %%
#Argentina

url = "https://open.spotify.com/playlist/37i9dQZEVXbJajpaXyaKll"

web2 = requests.get(url).text

soup = BeautifulSoup(web2, "html.parser")

# %%
Artists_Aa = list()
Albums_Aa = list()
Global_songs_Aa = soup.find_all("a", tabindex = "-1")
for Aa in Global_songs_Aa:
    Global_songs_Aa = str(Aa)
    if "/album" in Global_songs_Aa:
        Albums_Aa.append(Global_songs_Aa)
    elif "/artist" in Global_songs_Aa:
        Artists_Aa.append(Global_songs_Aa)

# %%
for Aa in Albums_Aa :
    print(Aa)
# Out:
# <a href="/album/1dDXsrM0q5ZLxZptZOPBI2" tabindex="-1"><span dir="auto">TITAN</span></a>
# <a href="/album/6tUQPKlpR4x1gjrXTtOImI" tabindex="-1"><span dir="auto">abcdefu</span></a>
# <a href="/album/5nyjEGwzkTlPiQJBOGbJsq" tabindex="-1"><span dir="auto">Taca a Xereca pra Mim</span></a>
# <a href="/album/58cd90Jkrovggh556JPN9L" tabindex="-1"><span dir="auto">Do It To It</span></a>
# <a href="/album/51C7H8yHGV88GdxGtipO04" tabindex="-1"><span dir="auto">Pa Tra Rkt</span></a>
# <a href="/album/2b4wYjErjhZ0U05XpOnsoC" tabindex="-1"><span dir="auto">Otra Noche</span></a>
# <a href="/album/4TWsxSw8df17aja6JSaar5" tabindex="-1"><span dir="auto">Mon Amour (Remix)</span></a>
# <a href="/album/5pd8szgioNYz6oz5BUbyCr" tabindex="-1"><span dir="auto">Funky de Antes</span></a>
# <a href="/album/4hYYpUC8Ewb74tP23Y1lmM" tabindex="-1"><span dir="auto">MIDDLE OF THE NIGHT</span></a>
# <a href="/album/4Uf8BVznefnd2xZm2nRFUx" tabindex="-1"><span dir="auto">Notion</span></a>
# <a href="/album/7lR5tiB0EL8xr8HodoIXg7" tabindex="-1"><span dir="auto">Own Brand Freestyle</span></a>
# <a href="/album/0QCHhR6WxpMZBbI33s1bAf" tabindex="-1"><span dir="auto">Bar</span></a>
# <a href="/album/6kZ42qRrzov54LcAk4onW9" tabindex="-1"><span dir="auto">Red (Taylor's Version)</span></a>
# <a href="/album/1bTgKomQYSkKYPD9UI9W4b" tabindex="-1"><span dir="auto">Enemy (with JID) [from the series Arcane League of Legends]</span></a>
# <a href="/album/0Y4RPWAZZui6gUL1kwgND6" tabindex="-1"><span dir="auto">MIGNONNE (Mastered by Bernie Grundman)</span></a>
# <a href="/album/1wlVX8kC5op2dfnUKlqpMv" tabindex="-1"><span dir="auto">Conteo (Turreo Edit)</span></a>
# <a href="/album/4q4rHdKxyCzxuQrPcdjPyC" tabindex="-1"><span dir="auto">SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis and Moliy)</span></a>
# <a href="/album/23M1xUF2RoRSvXtpwQP4rJ" tabindex="-1"><span dir="auto">abcdefu (angrier)</span></a>
# <a href="/album/1eUE1BBbfwthTQl3sPgLAi" tabindex="-1"><span dir="auto">Fanática Sensual (Turreo Edit)</span></a>
# <a href="/album/4nJ65lptuDZXNr0deIWKiU" tabindex="-1"><span dir="auto">Queen Elizabitch</span></a>
# <a href="/album/1wStB4tocxl1PA6HMvyQtP" tabindex="-1"><span dir="auto">Sou Favela</span></a>
# <a href="/album/50SdnzlrXUMadt9JYeaJSh" tabindex="-1"><span dir="auto">Hecho En Medellín</span></a>
# <a href="/album/4cmu24lnj0NI8lHG6vra6h" tabindex="-1"><span dir="auto">Toxic</span></a>
# <a href="/album/7wHczdY0ek3FHnfVhk10om" tabindex="-1"><span dir="auto">The Lockdown Sessions</span></a>
# <a href="/album/3QgycjElVQUGvdWWewbHcE" tabindex="-1"><span dir="auto">15 Éxitos de Siempre Vol. 5</span></a>
# <a href="/album/39LyZrNGkbc2IUeVOhwmGU" tabindex="-1"><span dir="auto">LA FAMA (with The Weeknd)</span></a>
# <a href="/album/31WdgrOoDtafxlPZdnnMV7" tabindex="-1"><span dir="auto">Los Malvekes</span></a>
# <a href="/album/4mdWMx4VouAqsIqgLt3R6S" tabindex="-1"><span dir="auto">Tacones Rojos</span></a>
# <a href="/album/4qEsa8G94vXAr6IFwgPkk8" tabindex="-1"><span dir="auto">MESITA | Mission 05</span></a>
# <a href="/album/4WwUCAtmFpFAKrelj9zwSn" tabindex="-1"><span dir="auto">Don Omar RKT</span></a>

# %%
Aa_s = list()             
for Aa_ss in Albums_Aa:
    Aa_s1 = re.findall(r'>(.*)<',Aa_ss)[0]
    Aa_s2 = Aa_s1.replace('''<span dir="auto">''','')
    Aa_s3 =Aa_s2 .replace('''</span>''','')
    Aa_s.append(Aa_s3)

# %%
print(Aa_s)
# Out:
# ['TITAN', 'abcdefu', 'Taca a Xereca pra Mim', 'Do It To It', 'Pa Tra Rkt', 'Otra Noche', 'Mon Amour (Remix)', 'Funky de Antes', 'MIDDLE OF THE NIGHT', 'Notion', 'Own Brand Freestyle', 'Bar', "Red (Taylor's Version)", 'Enemy (with JID) [from the series Arcane League of Legends]', 'MIGNONNE (Mastered by Bernie Grundman)', 'Conteo (Turreo Edit)', 'SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis and Moliy)', 'abcdefu (angrier)', 'Fanática Sensual (Turreo Edit)', 'Queen Elizabitch', 'Sou Favela', 'Hecho En Medellín', 'Toxic', 'The Lockdown Sessions', '15 Éxitos de Siempre Vol. 5', 'LA FAMA (with The Weeknd)', 'Los Malvekes', 'Tacones Rojos', 'MESITA | Mission 05', 'Don Omar RKT']

# %%
df6 = pd.DataFrame(Aa_s,columns = ["Track Name"])
df6
# Out:
#                                            Track Name
# 0                                               TITAN
# 1                                             abcdefu
# 2                               Taca a Xereca pra Mim
# 3                                         Do It To It
# 4                                          Pa Tra Rkt
# 5                                          Otra Noche
# 6                                   Mon Amour (Remix)
# 7                                      Funky de Antes
# 8                                 MIDDLE OF THE NIGHT
# 9                                              Notion
# 10                                Own Brand Freestyle
# 11                                                Bar
# 12                             Red (Taylor's Version)
# 13  Enemy (with JID) [from the series Arcane Leagu...
# 14             MIGNONNE (Mastered by Bernie Grundman)
# 15                               Conteo (Turreo Edit)
# 16  SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis an...
# 17                                  abcdefu (angrier)
# 18                     Fanática Sensual (Turreo Edit)
# 19                                   Queen Elizabitch
# 20                                         Sou Favela
# 21                                  Hecho En Medellín
# 22                                              Toxic
# 23                              The Lockdown Sessions
# 24                        15 Éxitos de Siempre Vol. 5
# 25                          LA FAMA (with The Weeknd)
# 26                                       Los Malvekes
# 27                                      Tacones Rojos
# 28                                MESITA | Mission 05
# 29                                       Don Omar RKT

# %%
frames = [df4,df5,df6]
Dfs = pd.concat(frames)
Dfs
# Out:
#                    Track Name
# 0                          30
# 1       F*CK LOVE 3: OVER YOU
# 2                     abcdefu
# 3             Merry Christmas
# 4                     MONTERO
# ..                        ...
# 25  LA FAMA (with The Weeknd)
# 26               Los Malvekes
# 27              Tacones Rojos
# 28        MESITA | Mission 05
# 29               Don Omar RKT
#
# [90 rows x 1 columns]

# %%
Dfs = Df.reset_index(drop=True)
Dfs
# Out:
#                                            Track Name
# 0                                                  30
# 1                               F*CK LOVE 3: OVER YOU
# 2                                             abcdefu
# 3                                     Merry Christmas
# 4                                             MONTERO
# 5                          Dreamland (+ Bonus Levels)
# 6                               The Lockdown Sessions
# 7                                      LAST CHRISTMAS
# 8   Enemy (with JID) [from the series Arcane Leagu...
# 9                                                   =
# 10                                             La 167
# 11                 Christmas (Deluxe Special Edition)
# 12  Jingle Bell Rock/Captain Santa Claus (And His ...
# 13                                                  =
# 14                    Merry Christmas From Brenda Lee
# 15                             Red (Taylor's Version)
# 16                                               SOUR
# 17                                         Planet Her
# 18                                           I Hate U
# 19                                      Santa Tell Me
# 20                                        Do It To It
# 21                               Music Of The Spheres
# 22                  The Andy Williams Christmas Album
# 23                                         Planet Her
# 24                                            MONTERO
# 25                                         Planet Her
# 26                                                 30
# 27                                             Chosen
# 28                                             LALISA
# 29                                     CKay The First
# 30                                                 30
# 31                              F*CK LOVE 3: OVER YOU
# 32                                            abcdefu
# 33                                    Merry Christmas
# 34                                            MONTERO
# 35                         Dreamland (+ Bonus Levels)
# 36                              The Lockdown Sessions
# 37                                     LAST CHRISTMAS
# 38  Enemy (with JID) [from the series Arcane Leagu...
# 39                                                  =
# 40                                             La 167
# 41                 Christmas (Deluxe Special Edition)
# 42  Jingle Bell Rock/Captain Santa Claus (And His ...
# 43                                                  =
# 44                    Merry Christmas From Brenda Lee
# 45                             Red (Taylor's Version)
# 46                                               SOUR
# 47                                         Planet Her
# 48                                           I Hate U
# 49                                      Santa Tell Me
# 50                                        Do It To It
# 51                               Music Of The Spheres
# 52                  The Andy Williams Christmas Album
# 53                                         Planet Her
# 54                                            MONTERO
# 55                                         Planet Her
# 56                                                 30
# 57                                             Chosen
# 58                                             LALISA
# 59                                     CKay The First

# %%
Dfs.to_csv("Spotify_data_Analysis3.csv")

# %%
Data = pd.read_csv("Spotify_data_Analysis3.csv")
Data
# Out:
#     Unnamed: 0                                         Track Name
# 0            0                                                 30
# 1            1                              F*CK LOVE 3: OVER YOU
# 2            2                                            abcdefu
# 3            3                                    Merry Christmas
# 4            4                                            MONTERO
# 5            5                         Dreamland (+ Bonus Levels)
# 6            6                              The Lockdown Sessions
# 7            7                                     LAST CHRISTMAS
# 8            8  Enemy (with JID) [from the series Arcane Leagu...
# 9            9                                                  =
# 10          10                                             La 167
# 11          11                 Christmas (Deluxe Special Edition)
# 12          12  Jingle Bell Rock/Captain Santa Claus (And His ...
# 13          13                                                  =
# 14          14                    Merry Christmas From Brenda Lee
# 15          15                             Red (Taylor's Version)
# 16          16                                               SOUR
# 17          17                                         Planet Her
# 18          18                                           I Hate U
# 19          19                                      Santa Tell Me
# 20          20                                        Do It To It
# 21          21                               Music Of The Spheres
# 22          22                  The Andy Williams Christmas Album
# 23          23                                         Planet Her
# 24          24                                            MONTERO
# 25          25                                         Planet Her
# 26          26                                                 30
# 27          27                                             Chosen
# 28          28                                             LALISA
# 29          29                                     CKay The First
# 30          30                                                 30
# 31          31                              F*CK LOVE 3: OVER YOU
# 32          32                                            abcdefu
# 33          33                                    Merry Christmas
# 34          34                                            MONTERO
# 35          35                         Dreamland (+ Bonus Levels)
# 36          36                              The Lockdown Sessions
# 37          37                                     LAST CHRISTMAS
# 38          38  Enemy (with JID) [from the series Arcane Leagu...
# 39          39                                                  =
# 40          40                                             La 167
# 41          41                 Christmas (Deluxe Special Edition)
# 42          42  Jingle Bell Rock/Captain Santa Claus (And His ...
# 43          43                                                  =
# 44          44                    Merry Christmas From Brenda Lee
# 45          45                             Red (Taylor's Version)
# 46          46                                               SOUR
# 47          47                                         Planet Her
# 48          48                                           I Hate U
# 49          49                                      Santa Tell Me
# 50          50                                        Do It To It
# 51          51                               Music Of The Spheres
# 52          52                  The Andy Williams Christmas Album
# 53          53                                         Planet Her
# 54          54                                            MONTERO
# 55          55                                         Planet Her
# 56          56                                                 30
# 57          57                                             Chosen
# 58          58                                             LALISA
# 59          59                                     CKay The First

# %%
data1 = pd.read_csv("regional-gb-daily-latest(4).csv",header = [1])
data2 = pd.read_csv("Spotify_datas_1.csv")

# %%
data1
# Out:
#      Position                                         Track Name  \
# 0           1                                     Last Christmas
# 1           2                    All I Want for Christmas Is You
# 2           3                  Rockin' Around The Christmas Tree
# 3           4        It's Beginning to Look a Lot like Christmas
# 4           5                           Merry Christmas Everyone
# ..        ...                                                ...
# 195       196                                                UFO
# 196       197                                       Lucid Dreams
# 197       198  Oh Santa! (feat. Ariana Grande & Jennifer Hudson)
# 198       199                                            Holiday
# 199       200                                        To Be Loved
#
#               Artist  Streams  \
# 0              Wham!   584745
# 1       Mariah Carey   561256
# 2         Brenda Lee   423828
# 3      Michael Bublé   408165
# 4    Shakin' Stevens   404144
# ..               ...      ...
# 195   D-Block Europe    64615
# 196       Juice WRLD    64515
# 197     Mariah Carey    64398
# 198              KSI    64352
# 199            Adele    64328
#
#                                                    URL  Likes  Energy  \
# 0    https://open.spotify.com/track/2FRnf9qhLbvw8fu...  50000      21
# 1    https://open.spotify.com/track/0bYg9bo50gSsH3L...  49998      46
# 2    https://open.spotify.com/track/2EjXfH91m7f8HiJ...  49998      56
# 3    https://open.spotify.com/track/0lLdorYw7lVrJyd...  49998      67
# 4    https://open.spotify.com/track/2TE4xW3ImvpltVU...  49997      80
# ..                                                 ...    ...     ...
# 195  https://open.spotify.com/track/7G5VNGDnHt414Py...  49896      25
# 196  https://open.spotify.com/track/285pBltuF7vW8Te...  49896      59
# 197  https://open.spotify.com/track/2VkuxjlbnbaBiWY...  49896      65
# 198  https://open.spotify.com/track/14Bcv6siTBPw3Tl...  49895      74
# 199  https://open.spotify.com/track/10ImcQk9tihY1EK...  49894      86
#
#      Artist Followers
# 0              431730
# 1              400205
# 2              212623
# 3              168722
# 4               25818
# ..                ...
# 195            126358
# 196            288169
# 197            265592
# 198            489869
# 199            218234
#
# [200 rows x 8 columns]

# %%
data2.rename(columns = {'Song Name':'Track Name'}, inplace = True)
data2
# Out:
#      Unnamed: 0                             Track Name   Genre
# 0             0                            Motley Crew  HipHop
# 1             1      family ties (with Kendrick Lamar)  HipHop
# 2             2                  SUVs (Black on Black)  HipHop
# 3             3       Back On My Baby Jesus Sh!t AGAIN  HipHop
# 4             4                          KHALED KHALED  HipHop
# ..          ...                                    ...     ...
# 175         175                           Hands On You     Pop
# 176         176    Wandered To LA (with Justin Bieber)     Pop
# 177         177  Story Of My Life (feat. Trippie Redd)     Pop
# 178         178                        World Of Walker     Pop
# 179         179                                     30     Pop
#
# [180 rows x 3 columns]

# %%
data2
# Out:
#      Unnamed: 0                             Track Name   Genre
# 0             0                            Motley Crew  HipHop
# 1             1      family ties (with Kendrick Lamar)  HipHop
# 2             2                  SUVs (Black on Black)  HipHop
# 3             3       Back On My Baby Jesus Sh!t AGAIN  HipHop
# 4             4                          KHALED KHALED  HipHop
# ..          ...                                    ...     ...
# 175         175                           Hands On You     Pop
# 176         176    Wandered To LA (with Justin Bieber)     Pop
# 177         177  Story Of My Life (feat. Trippie Redd)     Pop
# 178         178                        World Of Walker     Pop
# 179         179                                     30     Pop
#
# [180 rows x 3 columns]

# %%
output1 = pd.merge(data1, data2, 
                   on='Track Name', 
                   how='inner')
output1
# Out:
#     Position                                  Track Name            Artist  \
# 0          6                                  Easy On Me             Adele
# 1         15                                     abcdefu             GAYLE
# 2         15                                     abcdefu             GAYLE
# 3         24                       Seventeen Going Under        Sam Fender
# 4         29                   STAY (with Justin Bieber)     The Kid LAROI
# 5         40                                 Do It To It            ACRAZE
# 6         41         Wandered To LA (with Justin Bieber)        Juice WRLD
# 7         41         Wandered To LA (with Justin Bieber)        Juice WRLD
# 8         42           INDUSTRY BABY (feat. Jack Harlow)         Lil Nas X
# 9         42           INDUSTRY BABY (feat. Jack Harlow)         Lil Nas X
# 10        68                                    I Hate U               SZA
# 11        68                                    I Hate U               SZA
# 12        77                       Smokin Out The Window        Bruno Mars
# 13       101                                 My Universe          Coldplay
# 14       102                           Where Are You Now  Lost Frequencies
# 15       143  Better Days (NEIKED x Mae Muller x Polo G)            NEIKED
# 16       155                                  I AM WOMAN         Emmy Meli
# 17       162                                    WYD Now?        Sadie Jean
#
#     Streams                                                URL  Likes  Energy  \
# 0    403568  https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997      89
# 1    302963  https://open.spotify.com/track/4fouWK6XVHhzl78...  49993      64
# 2    302963  https://open.spotify.com/track/4fouWK6XVHhzl78...  49993      64
# 3    252729  https://open.spotify.com/track/5rF6YUIlgiat22O...  49986      45
# 4    237051  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983      28
# 5    200487  https://open.spotify.com/track/20on25jryn53hWg...  49978      61
# 6    194227  https://open.spotify.com/track/1cA4wEmLkKlttS6...  49977      88
# 7    194227  https://open.spotify.com/track/1cA4wEmLkKlttS6...  49977      88
# 8    178617  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...  49977      61
# 9    178617  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...  49977      61
# 10   143862  https://open.spotify.com/track/5dXWFMwD7I7zXsI...  49964      43
# 11   143862  https://open.spotify.com/track/5dXWFMwD7I7zXsI...  49964      43
# 12   119793  https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959      57
# 13   102619  https://open.spotify.com/track/46HNZY1i7O6jwTA...  49946      83
# 14   101862  https://open.spotify.com/track/3uUuGVFu1V7jTQL...  49946      31
# 15    80140  https://open.spotify.com/track/6f5ExP43esnvdKP...  49926      61
# 16    77177  https://open.spotify.com/track/3nOz1U41SZZ0N3f...  49922      87
# 17    74671  https://open.spotify.com/track/3ZBeHiRJUj1vdiU...  49917      72
#
#     Artist Followers  Unnamed: 0   Genre
# 0             212909         123     Pop
# 1             287963         120     Pop
# 2             287963         151     Pop
# 3             279839         172     Pop
# 4             348873         121     Pop
# 5             392216         131     Pop
# 6             268017         132     Pop
# 7             268017         176     Pop
# 8             353463          10  HipHop
# 9             353463         126     Pop
# 10            413885         122     Pop
# 11            413885         159     Pop
# 12             60173         134     Pop
# 13             84584         139     Pop
# 14            484810         144     Pop
# 15            179851         142     Pop
# 16            444588         152     Pop
# 17            143587         157     Pop

# %%
output1.drop_duplicates(subset ="Track Name",
                     keep = False, inplace = True)
output1
# Out:
#     Position                                  Track Name            Artist  \
# 0          6                                  Easy On Me             Adele
# 3         24                       Seventeen Going Under        Sam Fender
# 4         29                   STAY (with Justin Bieber)     The Kid LAROI
# 5         40                                 Do It To It            ACRAZE
# 12        77                       Smokin Out The Window        Bruno Mars
# 13       101                                 My Universe          Coldplay
# 14       102                           Where Are You Now  Lost Frequencies
# 15       143  Better Days (NEIKED x Mae Muller x Polo G)            NEIKED
# 16       155                                  I AM WOMAN         Emmy Meli
# 17       162                                    WYD Now?        Sadie Jean
#
#     Streams                                                URL  Likes  Energy  \
# 0    403568  https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997      89
# 3    252729  https://open.spotify.com/track/5rF6YUIlgiat22O...  49986      45
# 4    237051  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983      28
# 5    200487  https://open.spotify.com/track/20on25jryn53hWg...  49978      61
# 12   119793  https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959      57
# 13   102619  https://open.spotify.com/track/46HNZY1i7O6jwTA...  49946      83
# 14   101862  https://open.spotify.com/track/3uUuGVFu1V7jTQL...  49946      31
# 15    80140  https://open.spotify.com/track/6f5ExP43esnvdKP...  49926      61
# 16    77177  https://open.spotify.com/track/3nOz1U41SZZ0N3f...  49922      87
# 17    74671  https://open.spotify.com/track/3ZBeHiRJUj1vdiU...  49917      72
#
#     Artist Followers  Unnamed: 0 Genre
# 0             212909         123   Pop
# 3             279839         172   Pop
# 4             348873         121   Pop
# 5             392216         131   Pop
# 12             60173         134   Pop
# 13             84584         139   Pop
# 14            484810         144   Pop
# 15            179851         142   Pop
# 16            444588         152   Pop
# 17            143587         157   Pop

# %%
Dataframe1 = output1.to_csv("Merge2.csv")
Dataframe1

# %%
Data3 = pd.read_csv("Merge2.csv")
Data3
# Out:
#    Unnamed: 0  Position                                  Track Name  \
# 0           0         6                                  Easy On Me
# 1           3        24                       Seventeen Going Under
# 2           4        29                   STAY (with Justin Bieber)
# 3           5        40                                 Do It To It
# 4          12        77                       Smokin Out The Window
# 5          13       101                                 My Universe
# 6          14       102                           Where Are You Now
# 7          15       143  Better Days (NEIKED x Mae Muller x Polo G)
# 8          16       155                                  I AM WOMAN
# 9          17       162                                    WYD Now?
#
#              Artist  Streams  \
# 0             Adele   403568
# 1        Sam Fender   252729
# 2     The Kid LAROI   237051
# 3            ACRAZE   200487
# 4        Bruno Mars   119793
# 5          Coldplay   102619
# 6  Lost Frequencies   101862
# 7            NEIKED    80140
# 8         Emmy Meli    77177
# 9        Sadie Jean    74671
#
#                                                  URL  Likes  Energy  \
# 0  https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997      89
# 1  https://open.spotify.com/track/5rF6YUIlgiat22O...  49986      45
# 2  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983      28
# 3  https://open.spotify.com/track/20on25jryn53hWg...  49978      61
# 4  https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959      57
# 5  https://open.spotify.com/track/46HNZY1i7O6jwTA...  49946      83
# 6  https://open.spotify.com/track/3uUuGVFu1V7jTQL...  49946      31
# 7  https://open.spotify.com/track/6f5ExP43esnvdKP...  49926      61
# 8  https://open.spotify.com/track/3nOz1U41SZZ0N3f...  49922      87
# 9  https://open.spotify.com/track/3ZBeHiRJUj1vdiU...  49917      72
#
#    Artist Followers  Unnamed: 0.1 Genre
# 0            212909           123   Pop
# 1            279839           172   Pop
# 2            348873           121   Pop
# 3            392216           131   Pop
# 4             60173           134   Pop
# 5             84584           139   Pop
# 6            484810           144   Pop
# 7            179851           142   Pop
# 8            444588           152   Pop
# 9            143587           157   Pop

# %%
Data4= pd.read_csv("regional-at-daily-latest(4).csv", header = [1])
Data4
# Out:
#      Position                                         Track Name  \
# 0           1                                            abcdefu
# 1           2                    All I Want for Christmas Is You
# 2           3                                     Last Christmas
# 3           4  DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred R...
# 4           5                                            Mit Dir
# ..        ...                                                ...
# 195       196                                  Following the Sun
# 196       197                       Ramenez la coupe à la maison
# 197       198                          Blame It On The Mistletoe
# 198       199                          Levitating (feat. DaBaby)
# 199       200                                                Run
#
#              Artist  Streams  \
# 0             GAYLE    46905
# 1      Mariah Carey    44412
# 2             Wham!    43424
# 3            KUMMER    34810
# 4              Sido    34490
# ..              ...      ...
# 195        SUPER-Hi     6196
# 196       Vegedream     6190
# 197  Ella Henderson     6182
# 198        Dua Lipa     6138
# 199     OneRepublic     6130
#
#                                                    URL  Likes  Energy  \
# 0    https://open.spotify.com/track/4fouWK6XVHhzl78...  49894      80
# 1    https://open.spotify.com/track/0bYg9bo50gSsH3L...  49854      81
# 2    https://open.spotify.com/track/2FRnf9qhLbvw8fu...  49757      33
# 3    https://open.spotify.com/track/2FQRZLR31e3423N...  49752      74
# 4    https://open.spotify.com/track/2xFMvrqk99biaLQ...  49699      40
# ..                                                 ...    ...     ...
# 195  https://open.spotify.com/track/5A5bLKdL5I3k3FT...  10698      73
# 196  https://open.spotify.com/track/1m0UFnuTktOkksv...  10578      77
# 197  https://open.spotify.com/track/110lWlsa8fJXgrr...  10419      65
# 198  https://open.spotify.com/track/5nujrmhLynf4yMo...  10130      86
# 199  https://open.spotify.com/track/6KL88T4Ma4ABXqz...  10090      84
#
#      Artist Followers
# 0              431730
# 1              400205
# 2              212623
# 3              168722
# 4               25818
# ..                ...
# 195            126358
# 196            288169
# 197            265592
# 198            489869
# 199            218234
#
# [200 rows x 8 columns]

# %%
data = pd.concat([Data3,Data4] , axis=0)
data
# Out:
#      Unnamed: 0  Position                    Track Name          Artist  \
# 0           0.0         6                    Easy On Me           Adele
# 1           3.0        24         Seventeen Going Under      Sam Fender
# 2           4.0        29     STAY (with Justin Bieber)   The Kid LAROI
# 3           5.0        40                   Do It To It          ACRAZE
# 4          12.0        77         Smokin Out The Window      Bruno Mars
# ..          ...       ...                           ...             ...
# 195         NaN       196             Following the Sun        SUPER-Hi
# 196         NaN       197  Ramenez la coupe à la maison       Vegedream
# 197         NaN       198     Blame It On The Mistletoe  Ella Henderson
# 198         NaN       199     Levitating (feat. DaBaby)        Dua Lipa
# 199         NaN       200                           Run     OneRepublic
#
#      Streams                                                URL  Likes  \
# 0     403568  https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997
# 1     252729  https://open.spotify.com/track/5rF6YUIlgiat22O...  49986
# 2     237051  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983
# 3     200487  https://open.spotify.com/track/20on25jryn53hWg...  49978
# 4     119793  https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959
# ..       ...                                                ...    ...
# 195     6196  https://open.spotify.com/track/5A5bLKdL5I3k3FT...  10698
# 196     6190  https://open.spotify.com/track/1m0UFnuTktOkksv...  10578
# 197     6182  https://open.spotify.com/track/110lWlsa8fJXgrr...  10419
# 198     6138  https://open.spotify.com/track/5nujrmhLynf4yMo...  10130
# 199     6130  https://open.spotify.com/track/6KL88T4Ma4ABXqz...  10090
#
#      Energy  Artist Followers  Unnamed: 0.1 Genre
# 0        89            212909         123.0   Pop
# 1        45            279839         172.0   Pop
# 2        28            348873         121.0   Pop
# 3        61            392216         131.0   Pop
# 4        57             60173         134.0   Pop
# ..      ...               ...           ...   ...
# 195      73            126358           NaN   NaN
# 196      77            288169           NaN   NaN
# 197      65            265592           NaN   NaN
# 198      86            489869           NaN   NaN
# 199      84            218234           NaN   NaN
#
# [210 rows x 11 columns]

# %%
data.drop(['Genre'],axis = 1, inplace = True)

# %%
Genres = ["HipHop","Indie","Pop","Party","Classical","Funk"]

call= list()
import random
for i in range(len(data)):
    ver =''.join(random.choice(Genres))
    call.append(ver)

# %%
data.drop(['Unnamed: 0'], axis=1, inplace = True)

# %%
data.drop(['Unnamed: 0.1'], axis=1, inplace = True)

# %%
duration=list()
for i in range (len(data)):
    time = np.random.randint(115,250)
    duration.append(time)

# %%
data.insert(8,"Duration in secs",duration,True)
data
# Out:
#      Position                    Track Name          Artist  Streams  \
# 0           6                    Easy On Me           Adele   403568
# 1          24         Seventeen Going Under      Sam Fender   252729
# 2          29     STAY (with Justin Bieber)   The Kid LAROI   237051
# 3          40                   Do It To It          ACRAZE   200487
# 4          77         Smokin Out The Window      Bruno Mars   119793
# ..        ...                           ...             ...      ...
# 195       196             Following the Sun        SUPER-Hi     6196
# 196       197  Ramenez la coupe à la maison       Vegedream     6190
# 197       198     Blame It On The Mistletoe  Ella Henderson     6182
# 198       199     Levitating (feat. DaBaby)        Dua Lipa     6138
# 199       200                           Run     OneRepublic     6130
#
#                                                    URL  Likes  Energy  \
# 0    https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997      89
# 1    https://open.spotify.com/track/5rF6YUIlgiat22O...  49986      45
# 2    https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983      28
# 3    https://open.spotify.com/track/20on25jryn53hWg...  49978      61
# 4    https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959      57
# ..                                                 ...    ...     ...
# 195  https://open.spotify.com/track/5A5bLKdL5I3k3FT...  10698      73
# 196  https://open.spotify.com/track/1m0UFnuTktOkksv...  10578      77
# 197  https://open.spotify.com/track/110lWlsa8fJXgrr...  10419      65
# 198  https://open.spotify.com/track/5nujrmhLynf4yMo...  10130      86
# 199  https://open.spotify.com/track/6KL88T4Ma4ABXqz...  10090      84
#
#      Artist Followers  Duration in secs
# 0              212909               140
# 1              279839               150
# 2              348873               244
# 3              392216               137
# 4               60173               131
# ..                ...               ...
# 195            126358               221
# 196            288169               230
# 197            265592               158
# 198            489869               151
# 199            218234               217
#
# [210 rows x 9 columns]

# %%
Rank = []
for i in range(len(data)):
    i=i+1
    Rank.append(i)

# %%
data.insert(6,"Rank",Rank,True)
data
# Out:
#      Position                    Track Name          Artist  Streams  \
# 0           6                    Easy On Me           Adele   403568
# 1          24         Seventeen Going Under      Sam Fender   252729
# 2          29     STAY (with Justin Bieber)   The Kid LAROI   237051
# 3          40                   Do It To It          ACRAZE   200487
# 4          77         Smokin Out The Window      Bruno Mars   119793
# ..        ...                           ...             ...      ...
# 195       196             Following the Sun        SUPER-Hi     6196
# 196       197  Ramenez la coupe à la maison       Vegedream     6190
# 197       198     Blame It On The Mistletoe  Ella Henderson     6182
# 198       199     Levitating (feat. DaBaby)        Dua Lipa     6138
# 199       200                           Run     OneRepublic     6130
#
#                                                    URL  Likes  Rank  Energy  \
# 0    https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997     1      89
# 1    https://open.spotify.com/track/5rF6YUIlgiat22O...  49986     2      45
# 2    https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983     3      28
# 3    https://open.spotify.com/track/20on25jryn53hWg...  49978     4      61
# 4    https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959     5      57
# ..                                                 ...    ...   ...     ...
# 195  https://open.spotify.com/track/5A5bLKdL5I3k3FT...  10698   206      73
# 196  https://open.spotify.com/track/1m0UFnuTktOkksv...  10578   207      77
# 197  https://open.spotify.com/track/110lWlsa8fJXgrr...  10419   208      65
# 198  https://open.spotify.com/track/5nujrmhLynf4yMo...  10130   209      86
# 199  https://open.spotify.com/track/6KL88T4Ma4ABXqz...  10090   210      84
#
#      Artist Followers  Duration in secs
# 0              212909               140
# 1              279839               150
# 2              348873               244
# 3              392216               137
# 4               60173               131
# ..                ...               ...
# 195            126358               221
# 196            288169               230
# 197            265592               158
# 198            489869               151
# 199            218234               217
#
# [210 rows x 10 columns]

# %%
data
# Out:
#      Position                    Track Name          Artist  Streams  \
# 0           6                    Easy On Me           Adele   403568
# 1          24         Seventeen Going Under      Sam Fender   252729
# 2          29     STAY (with Justin Bieber)   The Kid LAROI   237051
# 3          40                   Do It To It          ACRAZE   200487
# 4          77         Smokin Out The Window      Bruno Mars   119793
# ..        ...                           ...             ...      ...
# 195       196             Following the Sun        SUPER-Hi     6196
# 196       197  Ramenez la coupe à la maison       Vegedream     6190
# 197       198     Blame It On The Mistletoe  Ella Henderson     6182
# 198       199     Levitating (feat. DaBaby)        Dua Lipa     6138
# 199       200                           Run     OneRepublic     6130
#
#                                                    URL  Likes  Rank  Energy  \
# 0    https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997     1      89
# 1    https://open.spotify.com/track/5rF6YUIlgiat22O...  49986     2      45
# 2    https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983     3      28
# 3    https://open.spotify.com/track/20on25jryn53hWg...  49978     4      61
# 4    https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959     5      57
# ..                                                 ...    ...   ...     ...
# 195  https://open.spotify.com/track/5A5bLKdL5I3k3FT...  10698   206      73
# 196  https://open.spotify.com/track/1m0UFnuTktOkksv...  10578   207      77
# 197  https://open.spotify.com/track/110lWlsa8fJXgrr...  10419   208      65
# 198  https://open.spotify.com/track/5nujrmhLynf4yMo...  10130   209      86
# 199  https://open.spotify.com/track/6KL88T4Ma4ABXqz...  10090   210      84
#
#      Artist Followers  Duration in secs
# 0              212909               140
# 1              279839               150
# 2              348873               244
# 3              392216               137
# 4               60173               131
# ..                ...               ...
# 195            126358               221
# 196            288169               230
# 197            265592               158
# 198            489869               151
# 199            218234               217
#
# [210 rows x 10 columns]

# %%
data.drop(['Position'], axis=1, inplace = True)

# %%
data
# Out:
#                        Track Name          Artist  Streams  \
# 0                      Easy On Me           Adele   403568
# 1           Seventeen Going Under      Sam Fender   252729
# 2       STAY (with Justin Bieber)   The Kid LAROI   237051
# 3                     Do It To It          ACRAZE   200487
# 4           Smokin Out The Window      Bruno Mars   119793
# ..                            ...             ...      ...
# 195             Following the Sun        SUPER-Hi     6196
# 196  Ramenez la coupe à la maison       Vegedream     6190
# 197     Blame It On The Mistletoe  Ella Henderson     6182
# 198     Levitating (feat. DaBaby)        Dua Lipa     6138
# 199                           Run     OneRepublic     6130
#
#                                                    URL  Likes  Rank  Energy  \
# 0    https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997     1      89
# 1    https://open.spotify.com/track/5rF6YUIlgiat22O...  49986     2      45
# 2    https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983     3      28
# 3    https://open.spotify.com/track/20on25jryn53hWg...  49978     4      61
# 4    https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959     5      57
# ..                                                 ...    ...   ...     ...
# 195  https://open.spotify.com/track/5A5bLKdL5I3k3FT...  10698   206      73
# 196  https://open.spotify.com/track/1m0UFnuTktOkksv...  10578   207      77
# 197  https://open.spotify.com/track/110lWlsa8fJXgrr...  10419   208      65
# 198  https://open.spotify.com/track/5nujrmhLynf4yMo...  10130   209      86
# 199  https://open.spotify.com/track/6KL88T4Ma4ABXqz...  10090   210      84
#
#      Artist Followers  Duration in secs
# 0              212909               140
# 1              279839               150
# 2              348873               244
# 3              392216               137
# 4               60173               131
# ..                ...               ...
# 195            126358               221
# 196            288169               230
# 197            265592               158
# 198            489869               151
# 199            218234               217
#
# [210 rows x 9 columns]

# %% [markdown]
# # DATA VISUALIZATION

# %%
data.isna().sum()
# Out:
# Track Name          0
# Artist              0
# Streams             0
# URL                 0
# Likes               0
# Rank                0
# Energy              0
# Artist Followers    0
# Duration in secs    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Name        210 non-null    object
#  1   Artist            210 non-null    object
#  2   Streams           210 non-null    int64
#  3   URL               210 non-null    object
#  4   Likes             210 non-null    int64
#  5   Rank              210 non-null    int64
#  6   Energy            210 non-null    int64
#  7   Artist Followers  210 non-null    int64
#  8   Duration in secs  210 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 16.4+ KB

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df = data.head(10)

df
# Out:
#                                    Track Name            Artist  Streams  \
# 0                                  Easy On Me             Adele   403568
# 1                       Seventeen Going Under        Sam Fender   252729
# 2                   STAY (with Justin Bieber)     The Kid LAROI   237051
# 3                                 Do It To It            ACRAZE   200487
# 4                       Smokin Out The Window        Bruno Mars   119793
# 5                                 My Universe          Coldplay   102619
# 6                           Where Are You Now  Lost Frequencies   101862
# 7  Better Days (NEIKED x Mae Muller x Polo G)            NEIKED    80140
# 8                                  I AM WOMAN         Emmy Meli    77177
# 9                                    WYD Now?        Sadie Jean    74671
#
#                                                  URL  Likes  Rank  Energy  \
# 0  https://open.spotify.com/track/46IZ0fSY2mpAikt...  49997     1      89
# 1  https://open.spotify.com/track/5rF6YUIlgiat22O...  49986     2      45
# 2  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  49983     3      28
# 3  https://open.spotify.com/track/20on25jryn53hWg...  49978     4      61
# 4  https://open.spotify.com/track/7sMBvZCSUl99bJL...  49959     5      57
# 5  https://open.spotify.com/track/46HNZY1i7O6jwTA...  49946     6      83
# 6  https://open.spotify.com/track/3uUuGVFu1V7jTQL...  49946     7      31
# 7  https://open.spotify.com/track/6f5ExP43esnvdKP...  49926     8      61
# 8  https://open.spotify.com/track/3nOz1U41SZZ0N3f...  49922     9      87
# 9  https://open.spotify.com/track/3ZBeHiRJUj1vdiU...  49917    10      72
#
#    Artist Followers  Duration in secs
# 0            212909               140
# 1            279839               150
# 2            348873               244
# 3            392216               137
# 4             60173               131
# 5             84584               136
# 6            484810               123
# 7            179851               168
# 8            444588               147
# 9            143587               177

# %%
#Barplot
sns.set(style = "whitegrid")
ax = sns.barplot(x='Artist',y='Artist Followers',data=df.sort_values(by='Artist Followers',ascending=False))
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %%
#Scatter plot

sns.scatterplot(x="Rank", y="Artist Followers", hue = "Artist" , data = df)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
#distplot

sns.distplot(data['Likes'],
             hist_kws=dict(edgecolor="green", linewidth=5))
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Likes', ylabel='Density'>

# %%
shorts = df.drop(['Track Name','Artist','URL'], axis='columns')
shorts
# Out:
#    Streams  Likes  Rank  Energy  Artist Followers  Duration in secs
# 0   403568  49997     1      89            212909               140
# 1   252729  49986     2      45            279839               150
# 2   237051  49983     3      28            348873               244
# 3   200487  49978     4      61            392216               137
# 4   119793  49959     5      57             60173               131
# 5   102619  49946     6      83             84584               136
# 6   101862  49946     7      31            484810               123
# 7    80140  49926     8      61            179851               168
# 8    77177  49922     9      87            444588               147
# 9    74671  49917    10      72            143587               177

# %%
corr=data.corr()
corr
# Out:
#                    Streams     Likes      Rank    Energy  Artist Followers  \
# Streams           1.000000  0.418599 -0.446095  0.031040         -0.003620
# Likes             0.418599  1.000000 -0.998996 -0.015381         -0.050606
# Rank             -0.446095 -0.998996  1.000000  0.009302          0.050877
# Energy            0.031040 -0.015381  0.009302  1.000000          0.010491
# Artist Followers -0.003620 -0.050606  0.050877  0.010491          1.000000
# Duration in secs -0.081285 -0.061954  0.063477 -0.039593         -0.076270
#
#                   Duration in secs
# Streams                  -0.081285
# Likes                    -0.061954
# Rank                      0.063477
# Energy                   -0.039593
# Artist Followers         -0.076270
# Duration in secs          1.000000

# %%
sns.heatmap(corr , annot= True)  
# displaying the plotted heatmap
plt.show()
